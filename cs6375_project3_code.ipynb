# %% [markdown]
# Imports:

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split, ConcatDataset
import pandas as pd
import time
import itertools
import random
import json
import os
import numpy as np
from pathlib import Path

# %% [markdown]
# Saving files in case runtime disconnects. This code will:
# 1. Check if the code is being run in Google Colab
# - If so, it will try to mount your google drive
# - Then it will save the files later to a directory called ml_experiment_results in MyDrive
# 2. If the code is not being run in Google Colab, it will be saved to your pc on a local directory called model_results
#
# This is just to save the output tables so that they aren't lost if the runtime suddenly disconnects

# %%
def get_save_directory():
    try:
        # Check if code is running in Google Colab
        import google.colab
        from google.colab import drive

        # Try to mount Drive (should skip if already mounted)
        try:
            drive.mount('/content/drive', force_remount=False)
        except:
            pass

        # Using a standard path in Drive that should work for everyone
        save_dir = Path('/content/drive/MyDrive/ml_experiment_results')
        print(f"Running in Colab - saving to Google Drive: {save_dir}")
        return save_dir
    except ImportError:
        # If not in Colab, use local directory
        save_dir = Path.cwd() / "model_results"
        print(f"Running locally - saving to: {save_dir}")
        return save_dir

# %% [markdown]
# Initializing Random_seed, architectures for both MLP and CNNs, and Hyperparameter Values
# - Note: Setting all random seeds to 73 for reproducibility

# %%
def set_all_seeds(seed=73):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_all_seeds(73)

# %%
CONFIG = {
    'random_seed': 73,
    'max_epochs': 20,
    'early_stop_patience': 3,
    'param_samples': 10,
    'device': torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    'save_dir': get_save_directory()
}

MLP_ARCHITECTURES = {
    "shallow": [128],
    "medium": [512, 156, 128],
    "deep": [1024, 512, 256, 128, 64]
}

CNN_ARCHITECTURES = {
    "baseline": "baseline_cnn",
    "enhanced": "enhanced_cnn",
    "deeper": "deeper_cnn"
}

PARAM_SPACE = list(itertools.product(
    [0.01, 0.001, 0.0001],  # learning rates
    [32, 64, 128],          # batch sizes
    ["Adam", "SGD"],        # optimizers
    [0.2, 0.5]              # dropouts
))
# Out:
# Mounted at /content/drive
# Running in Colab - saving to Google Drive: /content/drive/MyDrive/ml_experiment_results

# %% [markdown]
# Importing MNIST and CIFAR-10 datasets for both models:

# %%
def load_datasets(use_cnn=False):
    # Default is not cnn (MLP) If it is for CNN, we normalize it (don't flatten it yet)
    if use_cnn:
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5,), (0.5,))
        ])
    # Here we flatten it for the MLP model
    else:
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Lambda(lambda x: x.view(-1))
        ])

    # MNIST Dataset import - 50k training, 10k validation split
    mnist_full = datasets.MNIST('mnist_data', train=True, download=True, transform=transform)
    mnist_test = datasets.MNIST('mnist_data', train=False, download=True, transform=transform)
    mnist_train, mnist_val = random_split(mnist_full, [50000, 10000])

    # Again, if it's for CNN, we normalize, this time for 3 channels since these images are RGB (not grayscale)
    if use_cnn:
        cifar_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
    # If it's MLP we flatten it as before
    else:
        cifar_transform = transform

    # CIFAR Dataset import - 45k training, 5k validation split
    cifar_full = datasets.CIFAR10('cifar_data', train=True, download=True, transform=cifar_transform)
    cifar_test = datasets.CIFAR10('cifar_data', train=False, download=True, transform=cifar_transform)
    cifar_train, cifar_val = random_split(cifar_full, [45000, 5000])

    # Input dimensions for MNIST and CIFAR (to be used later)
    mnist_shape = (1, 28, 28) if use_cnn else 784
    cifar_shape = (3, 32, 32) if use_cnn else 3072

    return {
        'mnist': {'train': mnist_train, 'val': mnist_val, 'test': mnist_test, 'input_dim': mnist_shape},
        'cifar10': {'train': cifar_train, 'val': cifar_val, 'test': cifar_test, 'input_dim': cifar_shape}
    }

# %% [markdown]
# Defining base architecture for MLP:

# %%
# Basic MLP to work for all 3 architecture types
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_layers, dropout=0.0, num_classes=10):
        super(MLP, self).__init__()
        layers = []
        prev_dim = input_dim
        for h in hidden_layers:
            layers.append(nn.Linear(prev_dim, h))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(dropout))
            prev_dim = h
        layers.append(nn.Linear(prev_dim, num_classes))
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)

# %% [markdown]
# Defining 3 Architectures for CNNs

# %%
class BaselineCNN(nn.Module):
    def __init__(self, in_channels, dropout=0.0, num_classes=10):
        super(BaselineCNN, self).__init__()
        # 2 convolutional layers, chose kernel = 3, padding = 1 for simplicity
        self.conv1 = nn.Conv2d(in_channels, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        # + max pooling
        self.pool = nn.MaxPool2d(2, 2)

        self.fc_input_size = None
        self.fc = None
        self.dropout = nn.Dropout(dropout)
        self.num_classes = num_classes

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))

        # Dynamically creates the fully connected layer on the first pass
        if self.fc is None:
            self.fc_input_size = x.shape[1] * x.shape[2] * x.shape[3]
            self.fc = nn.Linear(self.fc_input_size, self.num_classes).to(x.device)

        x = x.view(x.size(0), -1)
        x = self.dropout(x)
        x = self.fc(x)
        return x

# %%
class EnhancedCNN(nn.Module):
  # Chose same parameters as before (kernel = 3, padding = 1), juts added batch normalization each time & dropout
    def __init__(self, in_channels, dropout=0.0, num_classes=10):
        super(EnhancedCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(dropout)

        self.fc_input_size = None
        self.fc = None
        self.num_classes = num_classes

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.dropout(x)
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = self.dropout(x)

        if self.fc is None:
            self.fc_input_size = x.shape[1] * x.shape[2] * x.shape[3]
            self.fc = nn.Linear(self.fc_input_size, self.num_classes).to(x.device)

        x = x.view(x.size(0), -1)
        x = self.dropout(x)
        x = self.fc(x)
        return x

# %%
class DeeperCNN(nn.Module):
  # Same as before, just added more layers of batch normalization and dropout, same kernel size and padding
    def __init__(self, in_channels, dropout=0.0, num_classes=10):
        super(DeeperCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(dropout)

        self.fc_input_size = None
        self.fc1 = None
        self.fc2 = None
        self.num_classes = num_classes

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.dropout(x)
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = self.dropout(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.dropout(x)

        if self.fc1 is None:
            self.fc_input_size = x.shape[1] * x.shape[2] * x.shape[3]
            self.fc1 = nn.Linear(self.fc_input_size, 256).to(x.device)
            self.fc2 = nn.Linear(256, self.num_classes).to(x.device)

        x = x.view(x.size(0), -1)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.fc2(x)
        return x

# %% [markdown]
# Model Training Functions

# %%
# Helper function to get the validation accuracy for a given model
def evaluate_model(model, dataloader, device, is_cnn = False):
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            # Only flatten for MLP
            if not is_cnn and len(images.shape) > 2:
                images = images.view(images.size(0), -1)

            outputs = model(images)
            predicted = outputs.argmax(dim=1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    return correct / total

# %%
def train_model(model, train_loader, val_loader, optimizer, device, criterion=nn.CrossEntropyLoss(),
early_stop_patience=3, max_epochs=20, is_cnn=False, fixed_epochs=None):
    model.to(device)
    best_val_acc = 0.0
    patience_counter = 0
    start_time = time.time()
    best_epoch = 0
    best_state = None
    # Training each model for maximum of 20 epochs
    # Added later: to avoid data leakage, when we retrain on the training + validation set,
    # we use the same number of epochs that we found in the hyperparameter tuning
    epochs_to_run = fixed_epochs if fixed_epochs else max_epochs
    for epoch in range(epochs_to_run):
        model.train()
        for X, y in train_loader:
            X, y = X.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(X)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

        if not fixed_epochs:
            val_acc = evaluate_model(model, val_loader, device, is_cnn)
            print(f"Epoch {epoch+1}: Validation Accuracy = {val_acc:.4f}")
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                best_epoch = epoch + 1
                patience_counter = 0
                best_state = model.state_dict()
            else:
                patience_counter += 1
                if patience_counter >= early_stop_patience:
                    print(f"Early stopping at epoch {epoch - 2}")
                    best_epoch = epoch - 2
                    break

    runtime = time.time() - start_time
    if fixed_epochs:
        best_val_acc = evaluate_model(model, val_loader, device, is_cnn)
        best_epoch = fixed_epochs
    elif best_state:
        model.load_state_dict(best_state)
    return best_val_acc, runtime, best_epoch

# %%
# Helper function for optimizers, uses momentum = 0.9 for SGD (decided not to tune this hyperparameter)
def create_optimizer(opt_name, model_params, lr):
    if opt_name == "Adam":
        return optim.Adam(model_params, lr=lr)
    else:
        return optim.SGD(model_params, lr=lr, momentum=0.9)

# %%
# Helper function that creates the model type for each architecture from the name by calling previously defined functions
def create_model(model_type, arch_name, input_dim, dropout):
    if model_type == "MLP":
        hidden_layers = MLP_ARCHITECTURES[arch_name]
        return MLP(input_dim=input_dim, hidden_layers=hidden_layers, dropout=dropout)
    else:  # CNN
        in_channels = input_dim[0]  # 1 for MNIST, 3 for CIFAR
        if arch_name == "baseline":
            return BaselineCNN(in_channels=in_channels, dropout=dropout)
        elif arch_name == "enhanced":
            return EnhancedCNN(in_channels=in_channels, dropout=dropout)
        else:  # deeper
            return DeeperCNN(in_channels=in_channels, dropout=dropout)

# %% [markdown]
# Hyperparameter Tuning

# %%
# Combines all previous functions to get ideal hyperparameters
def run_experiments(dataset_name, input_dim, train_set, val_set, config, model_type="MLP"):
    random.seed(config['random_seed'])
    sampled_params = random.sample(PARAM_SPACE, config['param_samples'])
    results = []

    architectures = MLP_ARCHITECTURES if model_type == "MLP" else CNN_ARCHITECTURES
    is_cnn = (model_type == "CNN")

    for arch_name in architectures.keys():
        for lr, batch, opt_name, drop in sampled_params:
            # Setup data loaders
            train_loader = DataLoader(train_set, batch_size=batch, shuffle=True)
            val_loader = DataLoader(val_set, batch_size=batch, shuffle=False)

            # Create model and optimizer
            model = create_model(model_type, arch_name, input_dim, drop)
            optimizer = create_optimizer(opt_name, model.parameters(), lr)

            # Train
            print(f"\n{dataset_name} | {model_type} | {arch_name} | LR={lr} | Batch={batch} | Opt={opt_name} | Drop={drop}")
            val_acc, runtime, stop_epoch = train_model(
                model, train_loader, val_loader, optimizer,
                config['device'], max_epochs=config['max_epochs'],
                early_stop_patience=config['early_stop_patience'],
                is_cnn=is_cnn
            )

            print(f"Val Acc: {val_acc:.4f} | Runtime: {runtime:.2f}s | Stopped at epoch {stop_epoch}")

            results.append({
                "model_type": model_type,
                "architecture": arch_name,
                "learning_rate": lr,
                "batch_size": batch,
                "optimizer": opt_name,
                "dropout": drop,
                "stop_epoch": stop_epoch,
                "validation_accuracy": val_acc,
                "runtime": runtime
            })

    return results

# %% [markdown]
# Function for Getting the Test Accuracy on Models with Best Hyperparameters

# %%
def retrain_and_test(best_config, train_set, val_set, test_set, input_dim, config, model_type="MLP"):
    full_train_set = ConcatDataset([train_set, val_set])
    full_train_loader = DataLoader(full_train_set, batch_size=int(best_config["batch_size"]), shuffle=True)
    test_loader = DataLoader(test_set, batch_size=int(best_config["batch_size"]), shuffle=False)

    model = create_model(model_type, best_config["architecture"], input_dim, best_config["dropout"])
    model.to(config['device'])

    optimizer = create_optimizer(best_config["optimizer"], model.parameters(), best_config["learning_rate"])

    is_cnn = (model_type == "CNN")
    fixed_epochs = best_config["stop_epoch"]

    print(f"Retraining for {fixed_epochs} epochs (no early stopping)...")
    start_time = time.time()

    model.train()
    for epoch in range(fixed_epochs):
        for X, y in full_train_loader:
            X, y = X.to(config['device']), y.to(config['device'])
            optimizer.zero_grad()
            out = model(X)
            loss = nn.CrossEntropyLoss()(out, y)
            loss.backward()
            optimizer.step()
        print(f"Epoch {epoch+1}/{fixed_epochs} complete")

    runtime = time.time() - start_time

    test_acc = evaluate_model(model, test_loader, config['device'], is_cnn)
    print(f"Test accuracy: {test_acc:.4f} | Runtime: {runtime:.2f}s")

    return test_acc, runtime

# %% [markdown]
# Functions to Output Final Table (and save results in case runtime disconnects)

# %%
# Helper function to get best validation accuracy across all architectures
def get_best_config(results_list):
    return max(results_list, key=lambda x: x["validation_accuracy"])

# %% [markdown]
# Outputs the table given in the assignment

# %%
def summarize_results(results_list, best_test_acc=None, best_test_runtime=None, model_type="MLP"):
    unique_archs = sorted(set(r["architecture"] for r in results_list))

    # Group by architecture and find best run per architecture
    grouped_results = {arch: [] for arch in unique_archs}
    for run in results_list:
        grouped_results[run["architecture"]].append(run)

    best_runs = {arch: max(runs, key=lambda x: x["validation_accuracy"])
                 for arch, runs in grouped_results.items()}

    best_overall = max(results_list, key=lambda x: x["validation_accuracy"])

    # Build summary with proper architecture names
    arch_names = [arch.title() for arch in unique_archs] + ["Best Overall"]

    summary = {
        "Model": [model_type] * (len(unique_archs) + 1),
        "Architecture": arch_names,
        "Learning Rate": [best_runs[arch]["learning_rate"] for arch in unique_archs] + [best_overall["learning_rate"]],
        "Batch Size": [best_runs[arch]["batch_size"] for arch in unique_archs] + [best_overall["batch_size"]],
        "Optimizer": [best_runs[arch]["optimizer"] for arch in unique_archs] + [best_overall["optimizer"]],
        "Dropout": [best_runs[arch]["dropout"] for arch in unique_archs] + [best_overall["dropout"]],
        "Stop Epoch": [best_runs[arch]["stop_epoch"] for arch in unique_archs] + [best_overall["stop_epoch"]],
        "Validation Accuracy": [best_runs[arch]["validation_accuracy"] for arch in unique_archs] + [best_overall["validation_accuracy"]],
        "Runtime (min)": [best_runs[arch]["runtime"]/60 for arch in unique_archs] + [best_test_runtime/60 if best_test_runtime else None],
        "Test Accuracy": [None] * len(unique_archs) + [best_test_acc]
    }

    return pd.DataFrame(summary)

# %% [markdown]
# Saves results to JSON files (to be saved in Google Drive/locally later)

# %%
def save_results(results, filename, save_dir):
    save_dir.mkdir(parents=True, exist_ok=True)
    filepath = save_dir / filename
    with open(filepath, "w") as f:
        json.dump(results, f, indent=4)
    print(f"Saved to {filepath}")

def load_results(filename, save_dir):
    filepath = save_dir / filename
    if filepath.exists():
        with open(filepath, "r") as f:
            return json.load(f)
    return None

# %% [markdown]
# Calls on previous functions to run code for each model
# - Also checks if the file already exists so I don't have to re-run code that has already been executed if runtime disconnects for any reason

# %%
def run_model_experiments(datasets_dict, model_type, config):
    for dataset_name in ['mnist', 'cifar10']:
        data = datasets_dict[dataset_name]
        results_file = f"{dataset_name}_{model_type.lower()}_results.json"

        # Check if results already exist
        existing_results = load_results(results_file, config['save_dir'])
        if existing_results:
            print(f"Found existing results for {dataset_name} {model_type}, skipping experiments...")
            results = existing_results
        else:
            # Run experiments
            results = run_experiments(
                dataset_name.upper(),
                data['input_dim'],
                data['train'],
                data['val'],
                config,
                model_type=model_type
            )
            save_results(results, results_file, config['save_dir'])

        # Retrain best model and test
        best_config = get_best_config(results)
        print(f"\nRetraining best {model_type} model for {dataset_name.upper()}...")
        test_acc, test_runtime = retrain_and_test(
            best_config, data['train'], data['val'], data['test'],
            data['input_dim'], config, model_type=model_type
        )

        # Summarize and save
        df_summary = summarize_results(results, test_acc, test_runtime, model_type)
        summary_file = config['save_dir'] / f"{dataset_name}_{model_type.lower()}_table.csv"
        df_summary.to_csv(summary_file, index=False)
        print(df_summary)

# %% [markdown]
# Combines results into final 2 tables

# %%
def combine_results(config):
    for dataset_name in ['mnist', 'cifar10']:

        # Load individual result tables
        mlp_table_path = config['save_dir'] / f"{dataset_name}_mlp_table.csv"
        cnn_table_path = config['save_dir'] / f"{dataset_name}_cnn_table.csv"

        combined_dfs = []

        if mlp_table_path.exists():
            df_mlp = pd.read_csv(mlp_table_path)
            combined_dfs.append(df_mlp)
        else:
            print("Error")

        if cnn_table_path.exists():
            df_cnn = pd.read_csv(cnn_table_path)
            combined_dfs.append(df_cnn)
        else:
            print("Error")

        if combined_dfs:
            # Combine and save
            df_combined = pd.concat(combined_dfs, ignore_index=True)
            combined_file = config['save_dir'] / f"{dataset_name}_combined_table.csv"
            df_combined.to_csv(combined_file, index=False)
            print(df_combined.to_string(index=False))
        else:
            print("Error")

# %% [markdown]
# Main function that runs all the code, should take roughly 5 hours to run

# %%
print(f"Using device: {CONFIG['device']}")
print(f"Save directory: {CONFIG['save_dir']}")
set_all_seeds(CONFIG['random_seed'])

# Run MLP experiments
datasets_mlp = load_datasets(use_cnn=False)
run_model_experiments(datasets_mlp, "MLP", CONFIG)
# Out:
# Using device: cuda
# Save directory: /content/drive/MyDrive/ml_experiment_results
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.5MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 496kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.70MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 10.0MB/s]
# 100%|██████████| 170M/170M [00:08<00:00, 19.3MB/s]
# MNIST | MLP | shallow | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9311
# Epoch 2: Validation Accuracy = 0.9517
# Epoch 3: Validation Accuracy = 0.9582
# Epoch 4: Validation Accuracy = 0.9617
# Epoch 5: Validation Accuracy = 0.9640
# Epoch 6: Validation Accuracy = 0.9670
# Epoch 7: Validation Accuracy = 0.9689
# Epoch 8: Validation Accuracy = 0.9694
# Epoch 9: Validation Accuracy = 0.9702
# Epoch 10: Validation Accuracy = 0.9716
# Epoch 11: Validation Accuracy = 0.9707
# Epoch 12: Validation Accuracy = 0.9729
# Epoch 13: Validation Accuracy = 0.9734
# Epoch 14: Validation Accuracy = 0.9744
# Epoch 15: Validation Accuracy = 0.9741
# Epoch 16: Validation Accuracy = 0.9732
# Epoch 17: Validation Accuracy = 0.9732
# Early stopping at epoch 14
# Val Acc: 0.9744 | Runtime: 128.22s | Stopped at epoch 14
#
# MNIST | MLP | shallow | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9202
# Epoch 2: Validation Accuracy = 0.9397
# Epoch 3: Validation Accuracy = 0.9507
# Epoch 4: Validation Accuracy = 0.9540
# Epoch 5: Validation Accuracy = 0.9593
# Epoch 6: Validation Accuracy = 0.9619
# Epoch 7: Validation Accuracy = 0.9637
# Epoch 8: Validation Accuracy = 0.9641
# Epoch 9: Validation Accuracy = 0.9653
# Epoch 10: Validation Accuracy = 0.9673
# Epoch 11: Validation Accuracy = 0.9661
# Epoch 12: Validation Accuracy = 0.9697
# Epoch 13: Validation Accuracy = 0.9705
# Epoch 14: Validation Accuracy = 0.9701
# Epoch 15: Validation Accuracy = 0.9707
# Epoch 16: Validation Accuracy = 0.9716
# Epoch 17: Validation Accuracy = 0.9720
# Epoch 18: Validation Accuracy = 0.9721
# Epoch 19: Validation Accuracy = 0.9720
# Epoch 20: Validation Accuracy = 0.9719
# Val Acc: 0.9721 | Runtime: 145.58s | Stopped at epoch 18
#
# MNIST | MLP | shallow | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.8583
# Epoch 2: Validation Accuracy = 0.8916
# Epoch 3: Validation Accuracy = 0.9011
# Epoch 4: Validation Accuracy = 0.9105
# Epoch 5: Validation Accuracy = 0.9170
# Epoch 6: Validation Accuracy = 0.9206
# Epoch 7: Validation Accuracy = 0.9247
# Epoch 8: Validation Accuracy = 0.9285
# Epoch 9: Validation Accuracy = 0.9303
# Epoch 10: Validation Accuracy = 0.9346
# Epoch 11: Validation Accuracy = 0.9378
# Epoch 12: Validation Accuracy = 0.9401
# Epoch 13: Validation Accuracy = 0.9413
# Epoch 14: Validation Accuracy = 0.9436
# Epoch 15: Validation Accuracy = 0.9460
# Epoch 16: Validation Accuracy = 0.9485
# Epoch 17: Validation Accuracy = 0.9499
# Epoch 18: Validation Accuracy = 0.9517
# Epoch 19: Validation Accuracy = 0.9515
# Epoch 20: Validation Accuracy = 0.9537
# Val Acc: 0.9537 | Runtime: 136.49s | Stopped at epoch 20
#
# MNIST | MLP | shallow | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.4245
# Epoch 2: Validation Accuracy = 0.6142
# Epoch 3: Validation Accuracy = 0.7100
# Epoch 4: Validation Accuracy = 0.7495
# Epoch 5: Validation Accuracy = 0.7754
# Epoch 6: Validation Accuracy = 0.7964
# Epoch 7: Validation Accuracy = 0.8130
# Epoch 8: Validation Accuracy = 0.8269
# Epoch 9: Validation Accuracy = 0.8364
# Epoch 10: Validation Accuracy = 0.8452
# Epoch 11: Validation Accuracy = 0.8524
# Epoch 12: Validation Accuracy = 0.8586
# Epoch 13: Validation Accuracy = 0.8623
# Epoch 14: Validation Accuracy = 0.8668
# Epoch 15: Validation Accuracy = 0.8697
# Epoch 16: Validation Accuracy = 0.8714
# Epoch 17: Validation Accuracy = 0.8744
# Epoch 18: Validation Accuracy = 0.8762
# Epoch 19: Validation Accuracy = 0.8782
# Epoch 20: Validation Accuracy = 0.8801
# Val Acc: 0.8801 | Runtime: 145.46s | Stopped at epoch 20
#
# MNIST | MLP | shallow | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9054
# Epoch 2: Validation Accuracy = 0.9239
# Epoch 3: Validation Accuracy = 0.9338
# Epoch 4: Validation Accuracy = 0.9407
# Epoch 5: Validation Accuracy = 0.9448
# Epoch 6: Validation Accuracy = 0.9507
# Epoch 7: Validation Accuracy = 0.9526
# Epoch 8: Validation Accuracy = 0.9565
# Epoch 9: Validation Accuracy = 0.9578
# Epoch 10: Validation Accuracy = 0.9594
# Epoch 11: Validation Accuracy = 0.9608
# Epoch 12: Validation Accuracy = 0.9615
# Epoch 13: Validation Accuracy = 0.9633
# Epoch 14: Validation Accuracy = 0.9640
# Epoch 15: Validation Accuracy = 0.9639
# Epoch 16: Validation Accuracy = 0.9641
# Epoch 17: Validation Accuracy = 0.9661
# Epoch 18: Validation Accuracy = 0.9674
# Epoch 19: Validation Accuracy = 0.9685
# Epoch 20: Validation Accuracy = 0.9677
# Val Acc: 0.9685 | Runtime: 135.00s | Stopped at epoch 19
#
# MNIST | MLP | shallow | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.8782
# Epoch 2: Validation Accuracy = 0.9023
# Epoch 3: Validation Accuracy = 0.9105
# Epoch 4: Validation Accuracy = 0.9183
# Epoch 5: Validation Accuracy = 0.9239
# Epoch 6: Validation Accuracy = 0.9296
# Epoch 7: Validation Accuracy = 0.9357
# Epoch 8: Validation Accuracy = 0.9384
# Epoch 9: Validation Accuracy = 0.9440
# Epoch 10: Validation Accuracy = 0.9452
# Epoch 11: Validation Accuracy = 0.9481
# Epoch 12: Validation Accuracy = 0.9505
# Epoch 13: Validation Accuracy = 0.9517
# Epoch 14: Validation Accuracy = 0.9537
# Epoch 15: Validation Accuracy = 0.9544
# Epoch 16: Validation Accuracy = 0.9563
# Epoch 17: Validation Accuracy = 0.9573
# Epoch 18: Validation Accuracy = 0.9579
# Epoch 19: Validation Accuracy = 0.9586
# Epoch 20: Validation Accuracy = 0.9602
# Val Acc: 0.9602 | Runtime: 169.45s | Stopped at epoch 20
#
# MNIST | MLP | shallow | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9473
# Epoch 2: Validation Accuracy = 0.9538
# Epoch 3: Validation Accuracy = 0.9591
# Epoch 4: Validation Accuracy = 0.9573
# Epoch 5: Validation Accuracy = 0.9619
# Epoch 6: Validation Accuracy = 0.9642
# Epoch 7: Validation Accuracy = 0.9603
# Epoch 8: Validation Accuracy = 0.9648
# Epoch 9: Validation Accuracy = 0.9643
# Epoch 10: Validation Accuracy = 0.9637
# Epoch 11: Validation Accuracy = 0.9636
# Early stopping at epoch 8
# Val Acc: 0.9648 | Runtime: 75.15s | Stopped at epoch 8
#
# MNIST | MLP | shallow | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.8496
# Epoch 2: Validation Accuracy = 0.8807
# Epoch 3: Validation Accuracy = 0.8943
# Epoch 4: Validation Accuracy = 0.9002
# Epoch 5: Validation Accuracy = 0.9068
# Epoch 6: Validation Accuracy = 0.9120
# Epoch 7: Validation Accuracy = 0.9143
# Epoch 8: Validation Accuracy = 0.9186
# Epoch 9: Validation Accuracy = 0.9219
# Epoch 10: Validation Accuracy = 0.9245
# Epoch 11: Validation Accuracy = 0.9261
# Epoch 12: Validation Accuracy = 0.9297
# Epoch 13: Validation Accuracy = 0.9307
# Epoch 14: Validation Accuracy = 0.9325
# Epoch 15: Validation Accuracy = 0.9347
# Epoch 16: Validation Accuracy = 0.9377
# Epoch 17: Validation Accuracy = 0.9395
# Epoch 18: Validation Accuracy = 0.9410
# Epoch 19: Validation Accuracy = 0.9435
# Epoch 20: Validation Accuracy = 0.9443
# Val Acc: 0.9443 | Runtime: 146.36s | Stopped at epoch 20
#
# MNIST | MLP | shallow | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.9383
# Epoch 2: Validation Accuracy = 0.9579
# Epoch 3: Validation Accuracy = 0.9623
# Epoch 4: Validation Accuracy = 0.9678
# Epoch 5: Validation Accuracy = 0.9700
# Epoch 6: Validation Accuracy = 0.9726
# Epoch 7: Validation Accuracy = 0.9734
# Epoch 8: Validation Accuracy = 0.9740
# Epoch 9: Validation Accuracy = 0.9740
# Epoch 10: Validation Accuracy = 0.9756
# Epoch 11: Validation Accuracy = 0.9753
# Epoch 12: Validation Accuracy = 0.9751
# Epoch 13: Validation Accuracy = 0.9759
# Epoch 14: Validation Accuracy = 0.9777
# Epoch 15: Validation Accuracy = 0.9759
# Epoch 16: Validation Accuracy = 0.9770
# Epoch 17: Validation Accuracy = 0.9778
# Epoch 18: Validation Accuracy = 0.9779
# Epoch 19: Validation Accuracy = 0.9776
# Epoch 20: Validation Accuracy = 0.9790
# Val Acc: 0.9790 | Runtime: 168.70s | Stopped at epoch 20
#
# MNIST | MLP | shallow | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.8794
# Epoch 2: Validation Accuracy = 0.9009
# Epoch 3: Validation Accuracy = 0.9119
# Epoch 4: Validation Accuracy = 0.9188
# Epoch 5: Validation Accuracy = 0.9255
# Epoch 6: Validation Accuracy = 0.9309
# Epoch 7: Validation Accuracy = 0.9331
# Epoch 8: Validation Accuracy = 0.9380
# Epoch 9: Validation Accuracy = 0.9407
# Epoch 10: Validation Accuracy = 0.9435
# Epoch 11: Validation Accuracy = 0.9465
# Epoch 12: Validation Accuracy = 0.9481
# Epoch 13: Validation Accuracy = 0.9499
# Epoch 14: Validation Accuracy = 0.9515
# Epoch 15: Validation Accuracy = 0.9528
# Epoch 16: Validation Accuracy = 0.9540
# Epoch 17: Validation Accuracy = 0.9557
# Epoch 18: Validation Accuracy = 0.9564
# Epoch 19: Validation Accuracy = 0.9570
# Epoch 20: Validation Accuracy = 0.9578
# Val Acc: 0.9578 | Runtime: 168.54s | Stopped at epoch 20
#
# MNIST | MLP | medium | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9514
# Epoch 2: Validation Accuracy = 0.9593
# Epoch 3: Validation Accuracy = 0.9655
# Epoch 4: Validation Accuracy = 0.9685
# Epoch 5: Validation Accuracy = 0.9722
# Epoch 6: Validation Accuracy = 0.9719
# Epoch 7: Validation Accuracy = 0.9738
# Epoch 8: Validation Accuracy = 0.9747
# Epoch 9: Validation Accuracy = 0.9750
# Epoch 10: Validation Accuracy = 0.9788
# Epoch 11: Validation Accuracy = 0.9756
# Epoch 12: Validation Accuracy = 0.9766
# Epoch 13: Validation Accuracy = 0.9749
# Early stopping at epoch 10
# Val Acc: 0.9788 | Runtime: 101.93s | Stopped at epoch 10
#
# MNIST | MLP | medium | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9191
# Epoch 2: Validation Accuracy = 0.9503
# Epoch 3: Validation Accuracy = 0.9589
# Epoch 4: Validation Accuracy = 0.9637
# Epoch 5: Validation Accuracy = 0.9671
# Epoch 6: Validation Accuracy = 0.9681
# Epoch 7: Validation Accuracy = 0.9719
# Epoch 8: Validation Accuracy = 0.9713
# Epoch 9: Validation Accuracy = 0.9738
# Epoch 10: Validation Accuracy = 0.9746
# Epoch 11: Validation Accuracy = 0.9743
# Epoch 12: Validation Accuracy = 0.9768
# Epoch 13: Validation Accuracy = 0.9784
# Epoch 14: Validation Accuracy = 0.9763
# Epoch 15: Validation Accuracy = 0.9780
# Epoch 16: Validation Accuracy = 0.9779
# Early stopping at epoch 13
# Val Acc: 0.9784 | Runtime: 123.76s | Stopped at epoch 13
#
# MNIST | MLP | medium | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.8926
# Epoch 2: Validation Accuracy = 0.9157
# Epoch 3: Validation Accuracy = 0.9307
# Epoch 4: Validation Accuracy = 0.9398
# Epoch 5: Validation Accuracy = 0.9486
# Epoch 6: Validation Accuracy = 0.9535
# Epoch 7: Validation Accuracy = 0.9565
# Epoch 8: Validation Accuracy = 0.9590
# Epoch 9: Validation Accuracy = 0.9617
# Epoch 10: Validation Accuracy = 0.9626
# Epoch 11: Validation Accuracy = 0.9658
# Epoch 12: Validation Accuracy = 0.9678
# Epoch 13: Validation Accuracy = 0.9690
# Epoch 14: Validation Accuracy = 0.9696
# Epoch 15: Validation Accuracy = 0.9702
# Epoch 16: Validation Accuracy = 0.9718
# Epoch 17: Validation Accuracy = 0.9731
# Epoch 18: Validation Accuracy = 0.9748
# Epoch 19: Validation Accuracy = 0.9742
# Epoch 20: Validation Accuracy = 0.9762
# Val Acc: 0.9762 | Runtime: 140.98s | Stopped at epoch 20
#
# MNIST | MLP | medium | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.1083
# Epoch 2: Validation Accuracy = 0.1777
# Epoch 3: Validation Accuracy = 0.1957
# Epoch 4: Validation Accuracy = 0.2229
# Epoch 5: Validation Accuracy = 0.3482
# Epoch 6: Validation Accuracy = 0.4645
# Epoch 7: Validation Accuracy = 0.5130
# Epoch 8: Validation Accuracy = 0.4984
# Epoch 9: Validation Accuracy = 0.4581
# Epoch 10: Validation Accuracy = 0.4230
# Early stopping at epoch 7
# Val Acc: 0.5130 | Runtime: 76.84s | Stopped at epoch 7
#
# MNIST | MLP | medium | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.8780
# Epoch 2: Validation Accuracy = 0.9245
# Epoch 3: Validation Accuracy = 0.9467
# Epoch 4: Validation Accuracy = 0.9550
# Epoch 5: Validation Accuracy = 0.9610
# Epoch 6: Validation Accuracy = 0.9630
# Epoch 7: Validation Accuracy = 0.9649
# Epoch 8: Validation Accuracy = 0.9681
# Epoch 9: Validation Accuracy = 0.9702
# Epoch 10: Validation Accuracy = 0.9709
# Epoch 11: Validation Accuracy = 0.9720
# Epoch 12: Validation Accuracy = 0.9725
# Epoch 13: Validation Accuracy = 0.9736
# Epoch 14: Validation Accuracy = 0.9754
# Epoch 15: Validation Accuracy = 0.9746
# Epoch 16: Validation Accuracy = 0.9750
# Epoch 17: Validation Accuracy = 0.9746
# Early stopping at epoch 14
# Val Acc: 0.9754 | Runtime: 117.86s | Stopped at epoch 14
#
# MNIST | MLP | medium | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.7873
# Epoch 2: Validation Accuracy = 0.8896
# Epoch 3: Validation Accuracy = 0.9146
# Epoch 4: Validation Accuracy = 0.9258
# Epoch 5: Validation Accuracy = 0.9383
# Epoch 6: Validation Accuracy = 0.9471
# Epoch 7: Validation Accuracy = 0.9536
# Epoch 8: Validation Accuracy = 0.9576
# Epoch 9: Validation Accuracy = 0.9612
# Epoch 10: Validation Accuracy = 0.9618
# Epoch 11: Validation Accuracy = 0.9658
# Epoch 12: Validation Accuracy = 0.9665
# Epoch 13: Validation Accuracy = 0.9669
# Epoch 14: Validation Accuracy = 0.9699
# Epoch 15: Validation Accuracy = 0.9694
# Epoch 16: Validation Accuracy = 0.9716
# Epoch 17: Validation Accuracy = 0.9724
# Epoch 18: Validation Accuracy = 0.9734
# Epoch 19: Validation Accuracy = 0.9745
# Epoch 20: Validation Accuracy = 0.9741
# Val Acc: 0.9745 | Runtime: 185.78s | Stopped at epoch 19
#
# MNIST | MLP | medium | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9334
# Epoch 2: Validation Accuracy = 0.9363
# Epoch 3: Validation Accuracy = 0.9430
# Epoch 4: Validation Accuracy = 0.9359
# Epoch 5: Validation Accuracy = 0.9468
# Epoch 6: Validation Accuracy = 0.9455
# Epoch 7: Validation Accuracy = 0.9425
# Epoch 8: Validation Accuracy = 0.9423
# Early stopping at epoch 5
# Val Acc: 0.9468 | Runtime: 56.08s | Stopped at epoch 5
#
# MNIST | MLP | medium | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.5078
# Epoch 2: Validation Accuracy = 0.7851
# Epoch 3: Validation Accuracy = 0.8627
# Epoch 4: Validation Accuracy = 0.8851
# Epoch 5: Validation Accuracy = 0.9000
# Epoch 6: Validation Accuracy = 0.9092
# Epoch 7: Validation Accuracy = 0.9152
# Epoch 8: Validation Accuracy = 0.9218
# Epoch 9: Validation Accuracy = 0.9291
# Epoch 10: Validation Accuracy = 0.9365
# Epoch 11: Validation Accuracy = 0.9410
# Epoch 12: Validation Accuracy = 0.9466
# Epoch 13: Validation Accuracy = 0.9500
# Epoch 14: Validation Accuracy = 0.9526
# Epoch 15: Validation Accuracy = 0.9547
# Epoch 16: Validation Accuracy = 0.9585
# Epoch 17: Validation Accuracy = 0.9600
# Epoch 18: Validation Accuracy = 0.9616
# Epoch 19: Validation Accuracy = 0.9638
# Epoch 20: Validation Accuracy = 0.9647
# Val Acc: 0.9647 | Runtime: 154.12s | Stopped at epoch 20
#
# MNIST | MLP | medium | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.9479
# Epoch 2: Validation Accuracy = 0.9646
# Epoch 3: Validation Accuracy = 0.9709
# Epoch 4: Validation Accuracy = 0.9726
# Epoch 5: Validation Accuracy = 0.9765
# Epoch 6: Validation Accuracy = 0.9753
# Epoch 7: Validation Accuracy = 0.9771
# Epoch 8: Validation Accuracy = 0.9795
# Epoch 9: Validation Accuracy = 0.9790
# Epoch 10: Validation Accuracy = 0.9785
# Epoch 11: Validation Accuracy = 0.9789
# Early stopping at epoch 8
# Val Acc: 0.9795 | Runtime: 101.51s | Stopped at epoch 8
#
# MNIST | MLP | medium | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.6540
# Epoch 2: Validation Accuracy = 0.8672
# Epoch 3: Validation Accuracy = 0.9023
# Epoch 4: Validation Accuracy = 0.9186
# Epoch 5: Validation Accuracy = 0.9302
# Epoch 6: Validation Accuracy = 0.9413
# Epoch 7: Validation Accuracy = 0.9478
# Epoch 8: Validation Accuracy = 0.9538
# Epoch 9: Validation Accuracy = 0.9563
# Epoch 10: Validation Accuracy = 0.9596
# Epoch 11: Validation Accuracy = 0.9620
# Epoch 12: Validation Accuracy = 0.9649
# Epoch 13: Validation Accuracy = 0.9668
# Epoch 14: Validation Accuracy = 0.9679
# Epoch 15: Validation Accuracy = 0.9678
# Epoch 16: Validation Accuracy = 0.9691
# Epoch 17: Validation Accuracy = 0.9709
# Epoch 18: Validation Accuracy = 0.9712
# Epoch 19: Validation Accuracy = 0.9718
# Epoch 20: Validation Accuracy = 0.9741
# Val Acc: 0.9741 | Runtime: 184.86s | Stopped at epoch 20
#
# MNIST | MLP | deep | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9481
# Epoch 2: Validation Accuracy = 0.9585
# Epoch 3: Validation Accuracy = 0.9592
# Epoch 4: Validation Accuracy = 0.9665
# Epoch 5: Validation Accuracy = 0.9706
# Epoch 6: Validation Accuracy = 0.9736
# Epoch 7: Validation Accuracy = 0.9707
# Epoch 8: Validation Accuracy = 0.9763
# Epoch 9: Validation Accuracy = 0.9754
# Epoch 10: Validation Accuracy = 0.9753
# Epoch 11: Validation Accuracy = 0.9754
# Early stopping at epoch 8
# Val Acc: 0.9763 | Runtime: 91.73s | Stopped at epoch 8
#
# MNIST | MLP | deep | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.5875
# Epoch 2: Validation Accuracy = 0.9173
# Epoch 3: Validation Accuracy = 0.9438
# Epoch 4: Validation Accuracy = 0.9550
# Epoch 5: Validation Accuracy = 0.9593
# Epoch 6: Validation Accuracy = 0.9618
# Epoch 7: Validation Accuracy = 0.9671
# Epoch 8: Validation Accuracy = 0.9677
# Epoch 9: Validation Accuracy = 0.9709
# Epoch 10: Validation Accuracy = 0.9714
# Epoch 11: Validation Accuracy = 0.9735
# Epoch 12: Validation Accuracy = 0.9724
# Epoch 13: Validation Accuracy = 0.9734
# Epoch 14: Validation Accuracy = 0.9754
# Epoch 15: Validation Accuracy = 0.9758
# Epoch 16: Validation Accuracy = 0.9769
# Epoch 17: Validation Accuracy = 0.9770
# Epoch 18: Validation Accuracy = 0.9766
# Epoch 19: Validation Accuracy = 0.9779
# Epoch 20: Validation Accuracy = 0.9776
# Val Acc: 0.9779 | Runtime: 162.78s | Stopped at epoch 19
#
# MNIST | MLP | deep | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.8913
# Epoch 2: Validation Accuracy = 0.9224
# Epoch 3: Validation Accuracy = 0.9420
# Epoch 4: Validation Accuracy = 0.9545
# Epoch 5: Validation Accuracy = 0.9568
# Epoch 6: Validation Accuracy = 0.9641
# Epoch 7: Validation Accuracy = 0.9669
# Epoch 8: Validation Accuracy = 0.9693
# Epoch 9: Validation Accuracy = 0.9703
# Epoch 10: Validation Accuracy = 0.9721
# Epoch 11: Validation Accuracy = 0.9726
# Epoch 12: Validation Accuracy = 0.9726
# Epoch 13: Validation Accuracy = 0.9755
# Epoch 14: Validation Accuracy = 0.9768
# Epoch 15: Validation Accuracy = 0.9757
# Epoch 16: Validation Accuracy = 0.9761
# Epoch 17: Validation Accuracy = 0.9771
# Epoch 18: Validation Accuracy = 0.9781
# Epoch 19: Validation Accuracy = 0.9769
# Epoch 20: Validation Accuracy = 0.9780
# Val Acc: 0.9781 | Runtime: 145.68s | Stopped at epoch 18
#
# MNIST | MLP | deep | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.1060
# Epoch 2: Validation Accuracy = 0.1060
# Epoch 3: Validation Accuracy = 0.1060
# Epoch 4: Validation Accuracy = 0.1060
# Early stopping at epoch 1
# Val Acc: 0.1060 | Runtime: 32.43s | Stopped at epoch 1
#
# MNIST | MLP | deep | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.2390
# Epoch 2: Validation Accuracy = 0.6221
# Epoch 3: Validation Accuracy = 0.8974
# Epoch 4: Validation Accuracy = 0.9303
# Epoch 5: Validation Accuracy = 0.9449
# Epoch 6: Validation Accuracy = 0.9554
# Epoch 7: Validation Accuracy = 0.9572
# Epoch 8: Validation Accuracy = 0.9622
# Epoch 9: Validation Accuracy = 0.9650
# Epoch 10: Validation Accuracy = 0.9671
# Epoch 11: Validation Accuracy = 0.9696
# Epoch 12: Validation Accuracy = 0.9694
# Epoch 13: Validation Accuracy = 0.9723
# Epoch 14: Validation Accuracy = 0.9720
# Epoch 15: Validation Accuracy = 0.9751
# Epoch 16: Validation Accuracy = 0.9687
# Epoch 17: Validation Accuracy = 0.9740
# Epoch 18: Validation Accuracy = 0.9735
# Early stopping at epoch 15
# Val Acc: 0.9751 | Runtime: 128.83s | Stopped at epoch 15
#
# MNIST | MLP | deep | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.1195
# Epoch 2: Validation Accuracy = 0.2429
# Epoch 3: Validation Accuracy = 0.7852
# Epoch 4: Validation Accuracy = 0.8881
# Epoch 5: Validation Accuracy = 0.9263
# Epoch 6: Validation Accuracy = 0.9447
# Epoch 7: Validation Accuracy = 0.9515
# Epoch 8: Validation Accuracy = 0.9589
# Epoch 9: Validation Accuracy = 0.9636
# Epoch 10: Validation Accuracy = 0.9656
# Epoch 11: Validation Accuracy = 0.9668
# Epoch 12: Validation Accuracy = 0.9702
# Epoch 13: Validation Accuracy = 0.9706
# Epoch 14: Validation Accuracy = 0.9739
# Epoch 15: Validation Accuracy = 0.9738
# Epoch 16: Validation Accuracy = 0.9730
# Epoch 17: Validation Accuracy = 0.9741
# Epoch 18: Validation Accuracy = 0.9763
# Epoch 19: Validation Accuracy = 0.9756
# Epoch 20: Validation Accuracy = 0.9757
# Val Acc: 0.9763 | Runtime: 202.72s | Stopped at epoch 18
#
# MNIST | MLP | deep | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.7969
# Epoch 2: Validation Accuracy = 0.7605
# Epoch 3: Validation Accuracy = 0.8189
# Epoch 4: Validation Accuracy = 0.6780
# Epoch 5: Validation Accuracy = 0.6050
# Epoch 6: Validation Accuracy = 0.5618
# Early stopping at epoch 3
# Val Acc: 0.8189 | Runtime: 43.44s | Stopped at epoch 3
#
# MNIST | MLP | deep | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.1195
# Epoch 2: Validation Accuracy = 0.1195
# Epoch 3: Validation Accuracy = 0.2721
# Epoch 4: Validation Accuracy = 0.3758
# Epoch 5: Validation Accuracy = 0.6331
# Epoch 6: Validation Accuracy = 0.7582
# Epoch 7: Validation Accuracy = 0.8421
# Epoch 8: Validation Accuracy = 0.8824
# Epoch 9: Validation Accuracy = 0.9083
# Epoch 10: Validation Accuracy = 0.9216
# Epoch 11: Validation Accuracy = 0.9319
# Epoch 12: Validation Accuracy = 0.9394
# Epoch 13: Validation Accuracy = 0.9460
# Epoch 14: Validation Accuracy = 0.9478
# Epoch 15: Validation Accuracy = 0.9504
# Epoch 16: Validation Accuracy = 0.9554
# Epoch 17: Validation Accuracy = 0.9568
# Epoch 18: Validation Accuracy = 0.9569
# Epoch 19: Validation Accuracy = 0.9611
# Epoch 20: Validation Accuracy = 0.9622
# Val Acc: 0.9622 | Runtime: 165.74s | Stopped at epoch 20
#
# MNIST | MLP | deep | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.9322
# Epoch 2: Validation Accuracy = 0.9609
# Epoch 3: Validation Accuracy = 0.9688
# Epoch 4: Validation Accuracy = 0.9727
# Epoch 5: Validation Accuracy = 0.9711
# Epoch 6: Validation Accuracy = 0.9756
# Epoch 7: Validation Accuracy = 0.9763
# Epoch 8: Validation Accuracy = 0.9774
# Epoch 9: Validation Accuracy = 0.9788
# Epoch 10: Validation Accuracy = 0.9777
# Epoch 11: Validation Accuracy = 0.9790
# Epoch 12: Validation Accuracy = 0.9792
# Epoch 13: Validation Accuracy = 0.9752
# Epoch 14: Validation Accuracy = 0.9813
# Epoch 15: Validation Accuracy = 0.9797
# Epoch 16: Validation Accuracy = 0.9799
# Epoch 17: Validation Accuracy = 0.9822
# Epoch 18: Validation Accuracy = 0.9836
# Epoch 19: Validation Accuracy = 0.9803
# Epoch 20: Validation Accuracy = 0.9801
# Val Acc: 0.9836 | Runtime: 203.80s | Stopped at epoch 18
#
# MNIST | MLP | deep | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.1195
# Epoch 2: Validation Accuracy = 0.1198
# Epoch 3: Validation Accuracy = 0.2759
# Epoch 4: Validation Accuracy = 0.6435
# Epoch 5: Validation Accuracy = 0.7720
# Epoch 6: Validation Accuracy = 0.8910
# Epoch 7: Validation Accuracy = 0.9244
# Epoch 8: Validation Accuracy = 0.9384
# Epoch 9: Validation Accuracy = 0.9488
# Epoch 10: Validation Accuracy = 0.9507
# Epoch 11: Validation Accuracy = 0.9579
# Epoch 12: Validation Accuracy = 0.9587
# Epoch 13: Validation Accuracy = 0.9637
# Epoch 14: Validation Accuracy = 0.9632
# Epoch 15: Validation Accuracy = 0.9669
# Epoch 16: Validation Accuracy = 0.9669
# Epoch 17: Validation Accuracy = 0.9666
# Epoch 18: Validation Accuracy = 0.9708
# Epoch 19: Validation Accuracy = 0.9705
# Epoch 20: Validation Accuracy = 0.9718
# Val Acc: 0.9718 | Runtime: 200.98s | Stopped at epoch 20
# Saved to /content/drive/MyDrive/ml_experiment_results/mnist_mlp_results.json
#
# Retraining best MLP model for MNIST...
# Retraining for 18 epochs (no early stopping)...
# Epoch 1/18 complete
# Epoch 2/18 complete
# Epoch 3/18 complete
# Epoch 4/18 complete
# Epoch 5/18 complete
# Epoch 6/18 complete
# Epoch 7/18 complete
# Epoch 8/18 complete
# Epoch 9/18 complete
# Epoch 10/18 complete
# Epoch 11/18 complete
# Epoch 12/18 complete
# Epoch 13/18 complete
# Epoch 14/18 complete
# Epoch 15/18 complete
# Epoch 16/18 complete
# Epoch 17/18 complete
# Epoch 18/18 complete
# Test accuracy: 0.9829 | Runtime: 193.03s
#   Model  Architecture  Learning Rate  Batch Size Optimizer  Dropout  \
# 0   MLP          Deep           0.01          32       SGD      0.2
# 1   MLP        Medium           0.01          32       SGD      0.2
# 2   MLP       Shallow           0.01          32       SGD      0.2
# 3   MLP  Best Overall           0.01          32       SGD      0.2
#
#    Stop Epoch  Validation Accuracy  Runtime (min)  Test Accuracy
# 0          18               0.9836       3.396692            NaN
# 1           8               0.9795       1.691885            NaN
# 2          20               0.9790       2.811602            NaN
# 3          18               0.9836       3.217230         0.9829
#
# CIFAR10 | MLP | shallow | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.2972
# Epoch 2: Validation Accuracy = 0.2916
# Epoch 3: Validation Accuracy = 0.3060
# Epoch 4: Validation Accuracy = 0.3332
# Epoch 5: Validation Accuracy = 0.3394
# Epoch 6: Validation Accuracy = 0.3156
# Epoch 7: Validation Accuracy = 0.3082
# Epoch 8: Validation Accuracy = 0.3386
# Early stopping at epoch 5
# Val Acc: 0.3394 | Runtime: 59.89s | Stopped at epoch 5
#
# CIFAR10 | MLP | shallow | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3144
# Epoch 2: Validation Accuracy = 0.3152
# Epoch 3: Validation Accuracy = 0.3350
# Epoch 4: Validation Accuracy = 0.3376
# Epoch 5: Validation Accuracy = 0.3236
# Epoch 6: Validation Accuracy = 0.3132
# Epoch 7: Validation Accuracy = 0.3512
# Epoch 8: Validation Accuracy = 0.3662
# Epoch 9: Validation Accuracy = 0.3616
# Epoch 10: Validation Accuracy = 0.3704
# Epoch 11: Validation Accuracy = 0.3790
# Epoch 12: Validation Accuracy = 0.3860
# Epoch 13: Validation Accuracy = 0.3986
# Epoch 14: Validation Accuracy = 0.3844
# Epoch 15: Validation Accuracy = 0.3522
# Epoch 16: Validation Accuracy = 0.3854
# Early stopping at epoch 13
# Val Acc: 0.3986 | Runtime: 116.77s | Stopped at epoch 13
#
# CIFAR10 | MLP | shallow | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3362
# Epoch 2: Validation Accuracy = 0.3706
# Epoch 3: Validation Accuracy = 0.3888
# Epoch 4: Validation Accuracy = 0.3984
# Epoch 5: Validation Accuracy = 0.4086
# Epoch 6: Validation Accuracy = 0.4152
# Epoch 7: Validation Accuracy = 0.4162
# Epoch 8: Validation Accuracy = 0.4288
# Epoch 9: Validation Accuracy = 0.4324
# Epoch 10: Validation Accuracy = 0.4400
# Epoch 11: Validation Accuracy = 0.4364
# Epoch 12: Validation Accuracy = 0.4372
# Epoch 13: Validation Accuracy = 0.4488
# Epoch 14: Validation Accuracy = 0.4514
# Epoch 15: Validation Accuracy = 0.4578
# Epoch 16: Validation Accuracy = 0.4628
# Epoch 17: Validation Accuracy = 0.4618
# Epoch 18: Validation Accuracy = 0.4620
# Epoch 19: Validation Accuracy = 0.4706
# Epoch 20: Validation Accuracy = 0.4634
# Val Acc: 0.4706 | Runtime: 137.38s | Stopped at epoch 19
#
# CIFAR10 | MLP | shallow | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.2170
# Epoch 2: Validation Accuracy = 0.2668
# Epoch 3: Validation Accuracy = 0.2792
# Epoch 4: Validation Accuracy = 0.3004
# Epoch 5: Validation Accuracy = 0.3064
# Epoch 6: Validation Accuracy = 0.3172
# Epoch 7: Validation Accuracy = 0.3232
# Epoch 8: Validation Accuracy = 0.3292
# Epoch 9: Validation Accuracy = 0.3374
# Epoch 10: Validation Accuracy = 0.3386
# Epoch 11: Validation Accuracy = 0.3428
# Epoch 12: Validation Accuracy = 0.3478
# Epoch 13: Validation Accuracy = 0.3488
# Epoch 14: Validation Accuracy = 0.3520
# Epoch 15: Validation Accuracy = 0.3568
# Epoch 16: Validation Accuracy = 0.3614
# Epoch 17: Validation Accuracy = 0.3600
# Epoch 18: Validation Accuracy = 0.3660
# Epoch 19: Validation Accuracy = 0.3660
# Epoch 20: Validation Accuracy = 0.3690
# Val Acc: 0.3690 | Runtime: 145.36s | Stopped at epoch 20
#
# CIFAR10 | MLP | shallow | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3528
# Epoch 2: Validation Accuracy = 0.3590
# Epoch 3: Validation Accuracy = 0.3858
# Epoch 4: Validation Accuracy = 0.3768
# Epoch 5: Validation Accuracy = 0.3942
# Epoch 6: Validation Accuracy = 0.4036
# Epoch 7: Validation Accuracy = 0.4078
# Epoch 8: Validation Accuracy = 0.4052
# Epoch 9: Validation Accuracy = 0.4086
# Epoch 10: Validation Accuracy = 0.4162
# Epoch 11: Validation Accuracy = 0.4302
# Epoch 12: Validation Accuracy = 0.4178
# Epoch 13: Validation Accuracy = 0.4356
# Epoch 14: Validation Accuracy = 0.4348
# Epoch 15: Validation Accuracy = 0.4348
# Epoch 16: Validation Accuracy = 0.4376
# Epoch 17: Validation Accuracy = 0.4392
# Epoch 18: Validation Accuracy = 0.4356
# Epoch 19: Validation Accuracy = 0.4268
# Epoch 20: Validation Accuracy = 0.4310
# Early stopping at epoch 17
# Val Acc: 0.4392 | Runtime: 135.24s | Stopped at epoch 17
#
# CIFAR10 | MLP | shallow | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3548
# Epoch 2: Validation Accuracy = 0.3620
# Epoch 3: Validation Accuracy = 0.3998
# Epoch 4: Validation Accuracy = 0.4180
# Epoch 5: Validation Accuracy = 0.4378
# Epoch 6: Validation Accuracy = 0.4378
# Epoch 7: Validation Accuracy = 0.4436
# Epoch 8: Validation Accuracy = 0.4462
# Epoch 9: Validation Accuracy = 0.4650
# Epoch 10: Validation Accuracy = 0.4636
# Epoch 11: Validation Accuracy = 0.4646
# Epoch 12: Validation Accuracy = 0.4672
# Epoch 13: Validation Accuracy = 0.4816
# Epoch 14: Validation Accuracy = 0.4750
# Epoch 15: Validation Accuracy = 0.4872
# Epoch 16: Validation Accuracy = 0.4868
# Epoch 17: Validation Accuracy = 0.4976
# Epoch 18: Validation Accuracy = 0.4898
# Epoch 19: Validation Accuracy = 0.4976
# Epoch 20: Validation Accuracy = 0.5042
# Val Acc: 0.5042 | Runtime: 164.40s | Stopped at epoch 20
#
# CIFAR10 | MLP | shallow | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.0972
# Epoch 2: Validation Accuracy = 0.1024
# Epoch 3: Validation Accuracy = 0.0990
# Epoch 4: Validation Accuracy = 0.1014
# Epoch 5: Validation Accuracy = 0.0962
# Early stopping at epoch 2
# Val Acc: 0.1024 | Runtime: 34.54s | Stopped at epoch 2
#
# CIFAR10 | MLP | shallow | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3362
# Epoch 2: Validation Accuracy = 0.3592
# Epoch 3: Validation Accuracy = 0.3828
# Epoch 4: Validation Accuracy = 0.4012
# Epoch 5: Validation Accuracy = 0.4090
# Epoch 6: Validation Accuracy = 0.4176
# Epoch 7: Validation Accuracy = 0.4216
# Epoch 8: Validation Accuracy = 0.4348
# Epoch 9: Validation Accuracy = 0.4366
# Epoch 10: Validation Accuracy = 0.4492
# Epoch 11: Validation Accuracy = 0.4464
# Epoch 12: Validation Accuracy = 0.4520
# Epoch 13: Validation Accuracy = 0.4564
# Epoch 14: Validation Accuracy = 0.4608
# Epoch 15: Validation Accuracy = 0.4570
# Epoch 16: Validation Accuracy = 0.4740
# Epoch 17: Validation Accuracy = 0.4768
# Epoch 18: Validation Accuracy = 0.4770
# Epoch 19: Validation Accuracy = 0.4760
# Epoch 20: Validation Accuracy = 0.4796
# Val Acc: 0.4796 | Runtime: 145.60s | Stopped at epoch 20
#
# CIFAR10 | MLP | shallow | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3292
# Epoch 2: Validation Accuracy = 0.2816
# Epoch 3: Validation Accuracy = 0.3236
# Epoch 4: Validation Accuracy = 0.3200
# Early stopping at epoch 1
# Val Acc: 0.3292 | Runtime: 32.96s | Stopped at epoch 1
#
# CIFAR10 | MLP | shallow | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3368
# Epoch 2: Validation Accuracy = 0.3632
# Epoch 3: Validation Accuracy = 0.3842
# Epoch 4: Validation Accuracy = 0.4018
# Epoch 5: Validation Accuracy = 0.4078
# Epoch 6: Validation Accuracy = 0.4126
# Epoch 7: Validation Accuracy = 0.4148
# Epoch 8: Validation Accuracy = 0.4376
# Epoch 9: Validation Accuracy = 0.4372
# Epoch 10: Validation Accuracy = 0.4486
# Epoch 11: Validation Accuracy = 0.4444
# Epoch 12: Validation Accuracy = 0.4466
# Epoch 13: Validation Accuracy = 0.4606
# Epoch 14: Validation Accuracy = 0.4564
# Epoch 15: Validation Accuracy = 0.4556
# Epoch 16: Validation Accuracy = 0.4652
# Epoch 17: Validation Accuracy = 0.4536
# Epoch 18: Validation Accuracy = 0.4570
# Epoch 19: Validation Accuracy = 0.4648
# Early stopping at epoch 16
# Val Acc: 0.4652 | Runtime: 157.31s | Stopped at epoch 16
#
# CIFAR10 | MLP | medium | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.2734
# Epoch 2: Validation Accuracy = 0.3072
# Epoch 3: Validation Accuracy = 0.3278
# Epoch 4: Validation Accuracy = 0.2854
# Epoch 5: Validation Accuracy = 0.3042
# Epoch 6: Validation Accuracy = 0.3352
# Epoch 7: Validation Accuracy = 0.3278
# Epoch 8: Validation Accuracy = 0.3232
# Epoch 9: Validation Accuracy = 0.3174
# Early stopping at epoch 6
# Val Acc: 0.3352 | Runtime: 70.83s | Stopped at epoch 6
#
# CIFAR10 | MLP | medium | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3028
# Epoch 2: Validation Accuracy = 0.3364
# Epoch 3: Validation Accuracy = 0.3176
# Epoch 4: Validation Accuracy = 0.3454
# Epoch 5: Validation Accuracy = 0.3680
# Epoch 6: Validation Accuracy = 0.3592
# Epoch 7: Validation Accuracy = 0.3814
# Epoch 8: Validation Accuracy = 0.3862
# Epoch 9: Validation Accuracy = 0.3866
# Epoch 10: Validation Accuracy = 0.3878
# Epoch 11: Validation Accuracy = 0.3844
# Epoch 12: Validation Accuracy = 0.4040
# Epoch 13: Validation Accuracy = 0.4074
# Epoch 14: Validation Accuracy = 0.4096
# Epoch 15: Validation Accuracy = 0.4118
# Epoch 16: Validation Accuracy = 0.4202
# Epoch 17: Validation Accuracy = 0.4088
# Epoch 18: Validation Accuracy = 0.4148
# Epoch 19: Validation Accuracy = 0.4258
# Epoch 20: Validation Accuracy = 0.4240
# Val Acc: 0.4258 | Runtime: 154.16s | Stopped at epoch 19
#
# CIFAR10 | MLP | medium | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3312
# Epoch 2: Validation Accuracy = 0.3534
# Epoch 3: Validation Accuracy = 0.3786
# Epoch 4: Validation Accuracy = 0.4034
# Epoch 5: Validation Accuracy = 0.4122
# Epoch 6: Validation Accuracy = 0.4274
# Epoch 7: Validation Accuracy = 0.4374
# Epoch 8: Validation Accuracy = 0.4434
# Epoch 9: Validation Accuracy = 0.4502
# Epoch 10: Validation Accuracy = 0.4564
# Epoch 11: Validation Accuracy = 0.4626
# Epoch 12: Validation Accuracy = 0.4668
# Epoch 13: Validation Accuracy = 0.4752
# Epoch 14: Validation Accuracy = 0.4760
# Epoch 15: Validation Accuracy = 0.4808
# Epoch 16: Validation Accuracy = 0.4780
# Epoch 17: Validation Accuracy = 0.4804
# Epoch 18: Validation Accuracy = 0.4860
# Epoch 19: Validation Accuracy = 0.4876
# Epoch 20: Validation Accuracy = 0.5018
# Val Acc: 0.5018 | Runtime: 142.14s | Stopped at epoch 20
#
# CIFAR10 | MLP | medium | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.1306
# Epoch 2: Validation Accuracy = 0.1360
# Epoch 3: Validation Accuracy = 0.1380
# Epoch 4: Validation Accuracy = 0.1518
# Epoch 5: Validation Accuracy = 0.1564
# Epoch 6: Validation Accuracy = 0.1604
# Epoch 7: Validation Accuracy = 0.1760
# Epoch 8: Validation Accuracy = 0.1890
# Epoch 9: Validation Accuracy = 0.2078
# Epoch 10: Validation Accuracy = 0.2292
# Epoch 11: Validation Accuracy = 0.2398
# Epoch 12: Validation Accuracy = 0.2458
# Epoch 13: Validation Accuracy = 0.2590
# Epoch 14: Validation Accuracy = 0.2614
# Epoch 15: Validation Accuracy = 0.2656
# Epoch 16: Validation Accuracy = 0.2694
# Epoch 17: Validation Accuracy = 0.2682
# Epoch 18: Validation Accuracy = 0.2720
# Epoch 19: Validation Accuracy = 0.2730
# Epoch 20: Validation Accuracy = 0.2746
# Val Acc: 0.2746 | Runtime: 154.21s | Stopped at epoch 20
#
# CIFAR10 | MLP | medium | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.2434
# Epoch 2: Validation Accuracy = 0.3202
# Epoch 3: Validation Accuracy = 0.3404
# Epoch 4: Validation Accuracy = 0.3542
# Epoch 5: Validation Accuracy = 0.3694
# Epoch 6: Validation Accuracy = 0.3768
# Epoch 7: Validation Accuracy = 0.3624
# Epoch 8: Validation Accuracy = 0.3820
# Epoch 9: Validation Accuracy = 0.3998
# Epoch 10: Validation Accuracy = 0.4050
# Epoch 11: Validation Accuracy = 0.4092
# Epoch 12: Validation Accuracy = 0.4146
# Epoch 13: Validation Accuracy = 0.4138
# Epoch 14: Validation Accuracy = 0.4244
# Epoch 15: Validation Accuracy = 0.4294
# Epoch 16: Validation Accuracy = 0.4326
# Epoch 17: Validation Accuracy = 0.4324
# Epoch 18: Validation Accuracy = 0.4328
# Epoch 19: Validation Accuracy = 0.4370
# Epoch 20: Validation Accuracy = 0.4298
# Val Acc: 0.4370 | Runtime: 141.32s | Stopped at epoch 19
#
# CIFAR10 | MLP | medium | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.2702
# Epoch 2: Validation Accuracy = 0.3102
# Epoch 3: Validation Accuracy = 0.3450
# Epoch 4: Validation Accuracy = 0.3774
# Epoch 5: Validation Accuracy = 0.3984
# Epoch 6: Validation Accuracy = 0.4166
# Epoch 7: Validation Accuracy = 0.4136
# Epoch 8: Validation Accuracy = 0.4298
# Epoch 9: Validation Accuracy = 0.4364
# Epoch 10: Validation Accuracy = 0.4562
# Epoch 11: Validation Accuracy = 0.4488
# Epoch 12: Validation Accuracy = 0.4688
# Epoch 13: Validation Accuracy = 0.4654
# Epoch 14: Validation Accuracy = 0.4824
# Epoch 15: Validation Accuracy = 0.4746
# Epoch 16: Validation Accuracy = 0.4900
# Epoch 17: Validation Accuracy = 0.5002
# Epoch 18: Validation Accuracy = 0.5030
# Epoch 19: Validation Accuracy = 0.4868
# Epoch 20: Validation Accuracy = 0.5104
# Val Acc: 0.5104 | Runtime: 181.17s | Stopped at epoch 20
#
# CIFAR10 | MLP | medium | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.1390
# Epoch 2: Validation Accuracy = 0.1478
# Epoch 3: Validation Accuracy = 0.1586
# Epoch 4: Validation Accuracy = 0.1478
# Epoch 5: Validation Accuracy = 0.1368
# Epoch 6: Validation Accuracy = 0.1318
# Early stopping at epoch 3
# Val Acc: 0.1586 | Runtime: 42.50s | Stopped at epoch 3
#
# CIFAR10 | MLP | medium | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.2036
# Epoch 2: Validation Accuracy = 0.2760
# Epoch 3: Validation Accuracy = 0.3010
# Epoch 4: Validation Accuracy = 0.3242
# Epoch 5: Validation Accuracy = 0.3450
# Epoch 6: Validation Accuracy = 0.3648
# Epoch 7: Validation Accuracy = 0.3882
# Epoch 8: Validation Accuracy = 0.3950
# Epoch 9: Validation Accuracy = 0.4058
# Epoch 10: Validation Accuracy = 0.4094
# Epoch 11: Validation Accuracy = 0.4006
# Epoch 12: Validation Accuracy = 0.4282
# Epoch 13: Validation Accuracy = 0.4272
# Epoch 14: Validation Accuracy = 0.4346
# Epoch 15: Validation Accuracy = 0.4406
# Epoch 16: Validation Accuracy = 0.4512
# Epoch 17: Validation Accuracy = 0.4516
# Epoch 18: Validation Accuracy = 0.4610
# Epoch 19: Validation Accuracy = 0.4628
# Epoch 20: Validation Accuracy = 0.4608
# Val Acc: 0.4628 | Runtime: 153.77s | Stopped at epoch 19
#
# CIFAR10 | MLP | medium | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3516
# Epoch 2: Validation Accuracy = 0.3536
# Epoch 3: Validation Accuracy = 0.3818
# Epoch 4: Validation Accuracy = 0.4000
# Epoch 5: Validation Accuracy = 0.3976
# Epoch 6: Validation Accuracy = 0.4114
# Epoch 7: Validation Accuracy = 0.4314
# Epoch 8: Validation Accuracy = 0.4142
# Epoch 9: Validation Accuracy = 0.4396
# Epoch 10: Validation Accuracy = 0.4290
# Epoch 11: Validation Accuracy = 0.4662
# Epoch 12: Validation Accuracy = 0.4536
# Epoch 13: Validation Accuracy = 0.4574
# Epoch 14: Validation Accuracy = 0.4670
# Epoch 15: Validation Accuracy = 0.4438
# Epoch 16: Validation Accuracy = 0.4650
# Epoch 17: Validation Accuracy = 0.4526
# Early stopping at epoch 14
# Val Acc: 0.4670 | Runtime: 153.71s | Stopped at epoch 14
#
# CIFAR10 | MLP | medium | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.2206
# Epoch 2: Validation Accuracy = 0.2716
# Epoch 3: Validation Accuracy = 0.3194
# Epoch 4: Validation Accuracy = 0.3340
# Epoch 5: Validation Accuracy = 0.3486
# Epoch 6: Validation Accuracy = 0.3532
# Epoch 7: Validation Accuracy = 0.3816
# Epoch 8: Validation Accuracy = 0.3798
# Epoch 9: Validation Accuracy = 0.3902
# Epoch 10: Validation Accuracy = 0.4012
# Epoch 11: Validation Accuracy = 0.4092
# Epoch 12: Validation Accuracy = 0.4202
# Epoch 13: Validation Accuracy = 0.4206
# Epoch 14: Validation Accuracy = 0.4266
# Epoch 15: Validation Accuracy = 0.4182
# Epoch 16: Validation Accuracy = 0.4376
# Epoch 17: Validation Accuracy = 0.4274
# Epoch 18: Validation Accuracy = 0.4420
# Epoch 19: Validation Accuracy = 0.4470
# Epoch 20: Validation Accuracy = 0.4374
# Val Acc: 0.4470 | Runtime: 180.84s | Stopped at epoch 19
#
# CIFAR10 | MLP | deep | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.1902
# Epoch 2: Validation Accuracy = 0.1838
# Epoch 3: Validation Accuracy = 0.1936
# Epoch 4: Validation Accuracy = 0.2092
# Epoch 5: Validation Accuracy = 0.2282
# Epoch 6: Validation Accuracy = 0.2090
# Epoch 7: Validation Accuracy = 0.2208
# Epoch 8: Validation Accuracy = 0.2132
# Early stopping at epoch 5
# Val Acc: 0.2282 | Runtime: 65.71s | Stopped at epoch 5
#
# CIFAR10 | MLP | deep | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.1922
# Epoch 2: Validation Accuracy = 0.1970
# Epoch 3: Validation Accuracy = 0.1906
# Epoch 4: Validation Accuracy = 0.2118
# Epoch 5: Validation Accuracy = 0.2112
# Epoch 6: Validation Accuracy = 0.2484
# Epoch 7: Validation Accuracy = 0.2430
# Epoch 8: Validation Accuracy = 0.2770
# Epoch 9: Validation Accuracy = 0.3136
# Epoch 10: Validation Accuracy = 0.2796
# Epoch 11: Validation Accuracy = 0.3232
# Epoch 12: Validation Accuracy = 0.3316
# Epoch 13: Validation Accuracy = 0.3364
# Epoch 14: Validation Accuracy = 0.3298
# Epoch 15: Validation Accuracy = 0.3486
# Epoch 16: Validation Accuracy = 0.3546
# Epoch 17: Validation Accuracy = 0.3494
# Epoch 18: Validation Accuracy = 0.3470
# Epoch 19: Validation Accuracy = 0.3592
# Epoch 20: Validation Accuracy = 0.3700
# Val Acc: 0.3700 | Runtime: 160.83s | Stopped at epoch 20
#
# CIFAR10 | MLP | deep | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.2576
# Epoch 2: Validation Accuracy = 0.3246
# Epoch 3: Validation Accuracy = 0.3598
# Epoch 4: Validation Accuracy = 0.3742
# Epoch 5: Validation Accuracy = 0.3854
# Epoch 6: Validation Accuracy = 0.4152
# Epoch 7: Validation Accuracy = 0.4116
# Epoch 8: Validation Accuracy = 0.4124
# Epoch 9: Validation Accuracy = 0.4324
# Epoch 10: Validation Accuracy = 0.4314
# Epoch 11: Validation Accuracy = 0.4532
# Epoch 12: Validation Accuracy = 0.4570
# Epoch 13: Validation Accuracy = 0.4580
# Epoch 14: Validation Accuracy = 0.4736
# Epoch 15: Validation Accuracy = 0.4750
# Epoch 16: Validation Accuracy = 0.4736
# Epoch 17: Validation Accuracy = 0.4818
# Epoch 18: Validation Accuracy = 0.4822
# Epoch 19: Validation Accuracy = 0.4934
# Epoch 20: Validation Accuracy = 0.4920
# Val Acc: 0.4934 | Runtime: 145.69s | Stopped at epoch 19
#
# CIFAR10 | MLP | deep | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.1018
# Epoch 2: Validation Accuracy = 0.1018
# Epoch 3: Validation Accuracy = 0.1018
# Epoch 4: Validation Accuracy = 0.1018
# Early stopping at epoch 1
# Val Acc: 0.1018 | Runtime: 32.01s | Stopped at epoch 1
#
# CIFAR10 | MLP | deep | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.1058
# Epoch 2: Validation Accuracy = 0.1876
# Epoch 3: Validation Accuracy = 0.2222
# Epoch 4: Validation Accuracy = 0.2568
# Epoch 5: Validation Accuracy = 0.2606
# Epoch 6: Validation Accuracy = 0.2544
# Epoch 7: Validation Accuracy = 0.2678
# Epoch 8: Validation Accuracy = 0.2714
# Epoch 9: Validation Accuracy = 0.2700
# Epoch 10: Validation Accuracy = 0.2782
# Epoch 11: Validation Accuracy = 0.2882
# Epoch 12: Validation Accuracy = 0.2986
# Epoch 13: Validation Accuracy = 0.3090
# Epoch 14: Validation Accuracy = 0.3200
# Epoch 15: Validation Accuracy = 0.3310
# Epoch 16: Validation Accuracy = 0.3456
# Epoch 17: Validation Accuracy = 0.3406
# Epoch 18: Validation Accuracy = 0.3560
# Epoch 19: Validation Accuracy = 0.3438
# Epoch 20: Validation Accuracy = 0.3486
# Val Acc: 0.3560 | Runtime: 143.88s | Stopped at epoch 18
#
# CIFAR10 | MLP | deep | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.1322
# Epoch 2: Validation Accuracy = 0.1802
# Epoch 3: Validation Accuracy = 0.2026
# Epoch 4: Validation Accuracy = 0.2092
# Epoch 5: Validation Accuracy = 0.2342
# Epoch 6: Validation Accuracy = 0.2768
# Epoch 7: Validation Accuracy = 0.2844
# Epoch 8: Validation Accuracy = 0.3268
# Epoch 9: Validation Accuracy = 0.3476
# Epoch 10: Validation Accuracy = 0.3800
# Epoch 11: Validation Accuracy = 0.3826
# Epoch 12: Validation Accuracy = 0.3962
# Epoch 13: Validation Accuracy = 0.4164
# Epoch 14: Validation Accuracy = 0.4212
# Epoch 15: Validation Accuracy = 0.4224
# Epoch 16: Validation Accuracy = 0.4360
# Epoch 17: Validation Accuracy = 0.4506
# Epoch 18: Validation Accuracy = 0.4316
# Epoch 19: Validation Accuracy = 0.4532
# Epoch 20: Validation Accuracy = 0.4572
# Val Acc: 0.4572 | Runtime: 193.69s | Stopped at epoch 20
#
# CIFAR10 | MLP | deep | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.0968
# Epoch 2: Validation Accuracy = 0.1014
# Epoch 3: Validation Accuracy = 0.1048
# Epoch 4: Validation Accuracy = 0.0990
# Epoch 5: Validation Accuracy = 0.1018
# Epoch 6: Validation Accuracy = 0.0986
# Early stopping at epoch 3
# Val Acc: 0.1048 | Runtime: 43.65s | Stopped at epoch 3
#
# CIFAR10 | MLP | deep | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.0996
# Epoch 2: Validation Accuracy = 0.1776
# Epoch 3: Validation Accuracy = 0.1710
# Epoch 4: Validation Accuracy = 0.1904
# Epoch 5: Validation Accuracy = 0.2036
# Epoch 6: Validation Accuracy = 0.2182
# Epoch 7: Validation Accuracy = 0.2482
# Epoch 8: Validation Accuracy = 0.2772
# Epoch 9: Validation Accuracy = 0.2812
# Epoch 10: Validation Accuracy = 0.2900
# Epoch 11: Validation Accuracy = 0.2980
# Epoch 12: Validation Accuracy = 0.3000
# Epoch 13: Validation Accuracy = 0.3190
# Epoch 14: Validation Accuracy = 0.3284
# Epoch 15: Validation Accuracy = 0.3398
# Epoch 16: Validation Accuracy = 0.3540
# Epoch 17: Validation Accuracy = 0.3642
# Epoch 18: Validation Accuracy = 0.3886
# Epoch 19: Validation Accuracy = 0.3858
# Epoch 20: Validation Accuracy = 0.3970
# Val Acc: 0.3970 | Runtime: 161.86s | Stopped at epoch 20
#
# CIFAR10 | MLP | deep | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.2798
# Epoch 2: Validation Accuracy = 0.3314
# Epoch 3: Validation Accuracy = 0.3614
# Epoch 4: Validation Accuracy = 0.3924
# Epoch 5: Validation Accuracy = 0.3766
# Epoch 6: Validation Accuracy = 0.4088
# Epoch 7: Validation Accuracy = 0.4004
# Epoch 8: Validation Accuracy = 0.4378
# Epoch 9: Validation Accuracy = 0.4480
# Epoch 10: Validation Accuracy = 0.4502
# Epoch 11: Validation Accuracy = 0.4472
# Epoch 12: Validation Accuracy = 0.4592
# Epoch 13: Validation Accuracy = 0.4516
# Epoch 14: Validation Accuracy = 0.4544
# Epoch 15: Validation Accuracy = 0.4766
# Epoch 16: Validation Accuracy = 0.4494
# Epoch 17: Validation Accuracy = 0.4884
# Epoch 18: Validation Accuracy = 0.4810
# Epoch 19: Validation Accuracy = 0.4850
# Epoch 20: Validation Accuracy = 0.4916
# Val Acc: 0.4916 | Runtime: 193.96s | Stopped at epoch 20
#
# CIFAR10 | MLP | deep | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.1132
# Epoch 2: Validation Accuracy = 0.1608
# Epoch 3: Validation Accuracy = 0.1894
# Epoch 4: Validation Accuracy = 0.2006
# Epoch 5: Validation Accuracy = 0.1986
# Epoch 6: Validation Accuracy = 0.2010
# Epoch 7: Validation Accuracy = 0.2014
# Epoch 8: Validation Accuracy = 0.2004
# Epoch 9: Validation Accuracy = 0.2048
# Epoch 10: Validation Accuracy = 0.2076
# Epoch 11: Validation Accuracy = 0.2164
# Epoch 12: Validation Accuracy = 0.2508
# Epoch 13: Validation Accuracy = 0.2630
# Epoch 14: Validation Accuracy = 0.2576
# Epoch 15: Validation Accuracy = 0.2812
# Epoch 16: Validation Accuracy = 0.2842
# Epoch 17: Validation Accuracy = 0.2896
# Epoch 18: Validation Accuracy = 0.2882
# Epoch 19: Validation Accuracy = 0.3170
# Epoch 20: Validation Accuracy = 0.3124
# Val Acc: 0.3170 | Runtime: 194.74s | Stopped at epoch 19
# Saved to /content/drive/MyDrive/ml_experiment_results/cifar10_mlp_results.json
#
# Retraining best MLP model for CIFAR10...
# Retraining for 20 epochs (no early stopping)...
# Epoch 1/20 complete
# Epoch 2/20 complete
# Epoch 3/20 complete
# Epoch 4/20 complete
# Epoch 5/20 complete
# Epoch 6/20 complete
# Epoch 7/20 complete
# Epoch 8/20 complete
# Epoch 9/20 complete
# Epoch 10/20 complete
# Epoch 11/20 complete
# Epoch 12/20 complete
# Epoch 13/20 complete
# Epoch 14/20 complete
# Epoch 15/20 complete
# Epoch 16/20 complete
# Epoch 17/20 complete
# Epoch 18/20 complete
# Epoch 19/20 complete
# Epoch 20/20 complete
# Test accuracy: 0.5105 | Runtime: 189.10s
#   Model  Architecture  Learning Rate  Batch Size Optimizer  Dropout  \
# 0   MLP          Deep         0.0001         128      Adam      0.2
# 1   MLP        Medium         0.0010          32       SGD      0.2
# 2   MLP       Shallow         0.0010          32       SGD      0.2
# 3   MLP  Best Overall         0.0010          32       SGD      0.2
#
#    Stop Epoch  Validation Accuracy  Runtime (min)  Test Accuracy
# 0          19               0.4934       2.428194            NaN
# 1          20               0.5104       3.019484            NaN
# 2          20               0.5042       2.740058            NaN
# 3          20               0.5104       3.151721         0.5105

# %%
# Run CNN exper iments
datasets_cnn = load_datasets(use_cnn=True)
run_model_experiments(datasets_cnn, "CNN", CONFIG)
# Out:
# MNIST | CNN | baseline | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9122
# Epoch 2: Validation Accuracy = 0.9298
# Epoch 3: Validation Accuracy = 0.9354
# Epoch 4: Validation Accuracy = 0.9417
# Epoch 5: Validation Accuracy = 0.9473
# Epoch 6: Validation Accuracy = 0.9517
# Epoch 7: Validation Accuracy = 0.9497
# Epoch 8: Validation Accuracy = 0.9539
# Epoch 9: Validation Accuracy = 0.9563
# Epoch 10: Validation Accuracy = 0.9586
# Epoch 11: Validation Accuracy = 0.9583
# Epoch 12: Validation Accuracy = 0.9604
# Epoch 13: Validation Accuracy = 0.9589
# Epoch 14: Validation Accuracy = 0.9595
# Epoch 15: Validation Accuracy = 0.9618
# Epoch 16: Validation Accuracy = 0.9624
# Epoch 17: Validation Accuracy = 0.9606
# Epoch 18: Validation Accuracy = 0.9638
# Epoch 19: Validation Accuracy = 0.9633
# Epoch 20: Validation Accuracy = 0.9630
# Val Acc: 0.9638 | Runtime: 272.27s | Stopped at epoch 18
#
# MNIST | CNN | baseline | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.8879
# Epoch 2: Validation Accuracy = 0.9183
# Epoch 3: Validation Accuracy = 0.9350
# Epoch 4: Validation Accuracy = 0.9386
# Epoch 5: Validation Accuracy = 0.9449
# Epoch 6: Validation Accuracy = 0.9481
# Epoch 7: Validation Accuracy = 0.9511
# Epoch 8: Validation Accuracy = 0.9510
# Epoch 9: Validation Accuracy = 0.9547
# Epoch 10: Validation Accuracy = 0.9552
# Epoch 11: Validation Accuracy = 0.9557
# Epoch 12: Validation Accuracy = 0.9591
# Epoch 13: Validation Accuracy = 0.9585
# Epoch 14: Validation Accuracy = 0.9583
# Epoch 15: Validation Accuracy = 0.9602
# Epoch 16: Validation Accuracy = 0.9626
# Epoch 17: Validation Accuracy = 0.9633
# Epoch 18: Validation Accuracy = 0.9631
# Epoch 19: Validation Accuracy = 0.9638
# Epoch 20: Validation Accuracy = 0.9652
# Val Acc: 0.9652 | Runtime: 268.25s | Stopped at epoch 20
#
# MNIST | CNN | baseline | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.7226
# Epoch 2: Validation Accuracy = 0.8020
# Epoch 3: Validation Accuracy = 0.8430
# Epoch 4: Validation Accuracy = 0.8676
# Epoch 5: Validation Accuracy = 0.8825
# Epoch 6: Validation Accuracy = 0.8946
# Epoch 7: Validation Accuracy = 0.9017
# Epoch 8: Validation Accuracy = 0.9100
# Epoch 9: Validation Accuracy = 0.9153
# Epoch 10: Validation Accuracy = 0.9190
# Epoch 11: Validation Accuracy = 0.9258
# Epoch 12: Validation Accuracy = 0.9286
# Epoch 13: Validation Accuracy = 0.9311
# Epoch 14: Validation Accuracy = 0.9341
# Epoch 15: Validation Accuracy = 0.9346
# Epoch 16: Validation Accuracy = 0.9365
# Epoch 17: Validation Accuracy = 0.9386
# Epoch 18: Validation Accuracy = 0.9401
# Epoch 19: Validation Accuracy = 0.9417
# Epoch 20: Validation Accuracy = 0.9438
# Val Acc: 0.9438 | Runtime: 253.25s | Stopped at epoch 20
#
# MNIST | CNN | baseline | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.1765
# Epoch 2: Validation Accuracy = 0.3481
# Epoch 3: Validation Accuracy = 0.4160
# Epoch 4: Validation Accuracy = 0.4938
# Epoch 5: Validation Accuracy = 0.5507
# Epoch 6: Validation Accuracy = 0.5786
# Epoch 7: Validation Accuracy = 0.6052
# Epoch 8: Validation Accuracy = 0.6313
# Epoch 9: Validation Accuracy = 0.6535
# Epoch 10: Validation Accuracy = 0.6648
# Epoch 11: Validation Accuracy = 0.6805
# Epoch 12: Validation Accuracy = 0.6940
# Epoch 13: Validation Accuracy = 0.7018
# Epoch 14: Validation Accuracy = 0.7101
# Epoch 15: Validation Accuracy = 0.7205
# Epoch 16: Validation Accuracy = 0.7277
# Epoch 17: Validation Accuracy = 0.7350
# Epoch 18: Validation Accuracy = 0.7424
# Epoch 19: Validation Accuracy = 0.7516
# Epoch 20: Validation Accuracy = 0.7594
# Val Acc: 0.7594 | Runtime: 266.42s | Stopped at epoch 20
#
# MNIST | CNN | baseline | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.8460
# Epoch 2: Validation Accuracy = 0.8882
# Epoch 3: Validation Accuracy = 0.9117
# Epoch 4: Validation Accuracy = 0.9239
# Epoch 5: Validation Accuracy = 0.9317
# Epoch 6: Validation Accuracy = 0.9360
# Epoch 7: Validation Accuracy = 0.9385
# Epoch 8: Validation Accuracy = 0.9419
# Epoch 9: Validation Accuracy = 0.9451
# Epoch 10: Validation Accuracy = 0.9480
# Epoch 11: Validation Accuracy = 0.9486
# Epoch 12: Validation Accuracy = 0.9526
# Epoch 13: Validation Accuracy = 0.9537
# Epoch 14: Validation Accuracy = 0.9531
# Epoch 15: Validation Accuracy = 0.9549
# Epoch 16: Validation Accuracy = 0.9554
# Epoch 17: Validation Accuracy = 0.9560
# Epoch 18: Validation Accuracy = 0.9570
# Epoch 19: Validation Accuracy = 0.9584
# Epoch 20: Validation Accuracy = 0.9590
# Val Acc: 0.9590 | Runtime: 250.81s | Stopped at epoch 20
#
# MNIST | CNN | baseline | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.7565
# Epoch 2: Validation Accuracy = 0.8435
# Epoch 3: Validation Accuracy = 0.8732
# Epoch 4: Validation Accuracy = 0.8950
# Epoch 5: Validation Accuracy = 0.9050
# Epoch 6: Validation Accuracy = 0.9172
# Epoch 7: Validation Accuracy = 0.9213
# Epoch 8: Validation Accuracy = 0.9269
# Epoch 9: Validation Accuracy = 0.9317
# Epoch 10: Validation Accuracy = 0.9351
# Epoch 11: Validation Accuracy = 0.9397
# Epoch 12: Validation Accuracy = 0.9408
# Epoch 13: Validation Accuracy = 0.9425
# Epoch 14: Validation Accuracy = 0.9454
# Epoch 15: Validation Accuracy = 0.9461
# Epoch 16: Validation Accuracy = 0.9498
# Epoch 17: Validation Accuracy = 0.9488
# Epoch 18: Validation Accuracy = 0.9500
# Epoch 19: Validation Accuracy = 0.9512
# Epoch 20: Validation Accuracy = 0.9518
# Val Acc: 0.9518 | Runtime: 298.92s | Stopped at epoch 20
#
# MNIST | CNN | baseline | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9380
# Epoch 2: Validation Accuracy = 0.9484
# Epoch 3: Validation Accuracy = 0.9531
# Epoch 4: Validation Accuracy = 0.9575
# Epoch 5: Validation Accuracy = 0.9620
# Epoch 6: Validation Accuracy = 0.9614
# Epoch 7: Validation Accuracy = 0.9616
# Epoch 8: Validation Accuracy = 0.9631
# Epoch 9: Validation Accuracy = 0.9654
# Epoch 10: Validation Accuracy = 0.9674
# Epoch 11: Validation Accuracy = 0.9684
# Epoch 12: Validation Accuracy = 0.9682
# Epoch 13: Validation Accuracy = 0.9663
# Epoch 14: Validation Accuracy = 0.9684
# Early stopping at epoch 11
# Val Acc: 0.9684 | Runtime: 176.98s | Stopped at epoch 11
#
# MNIST | CNN | baseline | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.6329
# Epoch 2: Validation Accuracy = 0.7528
# Epoch 3: Validation Accuracy = 0.8020
# Epoch 4: Validation Accuracy = 0.8389
# Epoch 5: Validation Accuracy = 0.8646
# Epoch 6: Validation Accuracy = 0.8769
# Epoch 7: Validation Accuracy = 0.8883
# Epoch 8: Validation Accuracy = 0.8974
# Epoch 9: Validation Accuracy = 0.9020
# Epoch 10: Validation Accuracy = 0.9091
# Epoch 11: Validation Accuracy = 0.9139
# Epoch 12: Validation Accuracy = 0.9192
# Epoch 13: Validation Accuracy = 0.9227
# Epoch 14: Validation Accuracy = 0.9253
# Epoch 15: Validation Accuracy = 0.9275
# Epoch 16: Validation Accuracy = 0.9298
# Epoch 17: Validation Accuracy = 0.9326
# Epoch 18: Validation Accuracy = 0.9331
# Epoch 19: Validation Accuracy = 0.9346
# Epoch 20: Validation Accuracy = 0.9364
# Val Acc: 0.9364 | Runtime: 265.74s | Stopped at epoch 20
#
# MNIST | CNN | baseline | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.9306
# Epoch 2: Validation Accuracy = 0.9526
# Epoch 3: Validation Accuracy = 0.9601
# Epoch 4: Validation Accuracy = 0.9612
# Epoch 5: Validation Accuracy = 0.9640
# Epoch 6: Validation Accuracy = 0.9667
# Epoch 7: Validation Accuracy = 0.9686
# Epoch 8: Validation Accuracy = 0.9682
# Epoch 9: Validation Accuracy = 0.9698
# Epoch 10: Validation Accuracy = 0.9710
# Epoch 11: Validation Accuracy = 0.9720
# Epoch 12: Validation Accuracy = 0.9723
# Epoch 13: Validation Accuracy = 0.9721
# Epoch 14: Validation Accuracy = 0.9735
# Epoch 15: Validation Accuracy = 0.9742
# Epoch 16: Validation Accuracy = 0.9744
# Epoch 17: Validation Accuracy = 0.9757
# Epoch 18: Validation Accuracy = 0.9754
# Epoch 19: Validation Accuracy = 0.9758
# Epoch 20: Validation Accuracy = 0.9753
# Val Acc: 0.9758 | Runtime: 297.64s | Stopped at epoch 19
#
# MNIST | CNN | baseline | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.7200
# Epoch 2: Validation Accuracy = 0.8099
# Epoch 3: Validation Accuracy = 0.8459
# Epoch 4: Validation Accuracy = 0.8674
# Epoch 5: Validation Accuracy = 0.8882
# Epoch 6: Validation Accuracy = 0.8985
# Epoch 7: Validation Accuracy = 0.9064
# Epoch 8: Validation Accuracy = 0.9120
# Epoch 9: Validation Accuracy = 0.9201
# Epoch 10: Validation Accuracy = 0.9238
# Epoch 11: Validation Accuracy = 0.9271
# Epoch 12: Validation Accuracy = 0.9318
# Epoch 13: Validation Accuracy = 0.9320
# Epoch 14: Validation Accuracy = 0.9341
# Epoch 15: Validation Accuracy = 0.9378
# Epoch 16: Validation Accuracy = 0.9398
# Epoch 17: Validation Accuracy = 0.9403
# Epoch 18: Validation Accuracy = 0.9397
# Epoch 19: Validation Accuracy = 0.9438
# Epoch 20: Validation Accuracy = 0.9436
# Val Acc: 0.9438 | Runtime: 297.40s | Stopped at epoch 19
#
# MNIST | CNN | enhanced | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.8948
# Epoch 2: Validation Accuracy = 0.9152
# Epoch 3: Validation Accuracy = 0.9298
# Epoch 4: Validation Accuracy = 0.9366
# Epoch 5: Validation Accuracy = 0.9394
# Epoch 6: Validation Accuracy = 0.9442
# Epoch 7: Validation Accuracy = 0.9475
# Epoch 8: Validation Accuracy = 0.9471
# Epoch 9: Validation Accuracy = 0.9481
# Epoch 10: Validation Accuracy = 0.9499
# Epoch 11: Validation Accuracy = 0.9514
# Epoch 12: Validation Accuracy = 0.9513
# Epoch 13: Validation Accuracy = 0.9521
# Epoch 14: Validation Accuracy = 0.9536
# Epoch 15: Validation Accuracy = 0.9529
# Epoch 16: Validation Accuracy = 0.9542
# Epoch 17: Validation Accuracy = 0.9522
# Epoch 18: Validation Accuracy = 0.9544
# Epoch 19: Validation Accuracy = 0.9567
# Epoch 20: Validation Accuracy = 0.9556
# Val Acc: 0.9567 | Runtime: 266.94s | Stopped at epoch 19
#
# MNIST | CNN | enhanced | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9034
# Epoch 2: Validation Accuracy = 0.9251
# Epoch 3: Validation Accuracy = 0.9323
# Epoch 4: Validation Accuracy = 0.9374
# Epoch 5: Validation Accuracy = 0.9401
# Epoch 6: Validation Accuracy = 0.9431
# Epoch 7: Validation Accuracy = 0.9444
# Epoch 8: Validation Accuracy = 0.9457
# Epoch 9: Validation Accuracy = 0.9463
# Epoch 10: Validation Accuracy = 0.9493
# Epoch 11: Validation Accuracy = 0.9480
# Epoch 12: Validation Accuracy = 0.9469
# Epoch 13: Validation Accuracy = 0.9514
# Epoch 14: Validation Accuracy = 0.9498
# Epoch 15: Validation Accuracy = 0.9497
# Epoch 16: Validation Accuracy = 0.9523
# Epoch 17: Validation Accuracy = 0.9505
# Epoch 18: Validation Accuracy = 0.9533
# Epoch 19: Validation Accuracy = 0.9520
# Epoch 20: Validation Accuracy = 0.9521
# Val Acc: 0.9533 | Runtime: 264.15s | Stopped at epoch 18
#
# MNIST | CNN | enhanced | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.8126
# Epoch 2: Validation Accuracy = 0.8739
# Epoch 3: Validation Accuracy = 0.8980
# Epoch 4: Validation Accuracy = 0.9088
# Epoch 5: Validation Accuracy = 0.9184
# Epoch 6: Validation Accuracy = 0.9235
# Epoch 7: Validation Accuracy = 0.9306
# Epoch 8: Validation Accuracy = 0.9332
# Epoch 9: Validation Accuracy = 0.9366
# Epoch 10: Validation Accuracy = 0.9403
# Epoch 11: Validation Accuracy = 0.9418
# Epoch 12: Validation Accuracy = 0.9448
# Epoch 13: Validation Accuracy = 0.9464
# Epoch 14: Validation Accuracy = 0.9469
# Epoch 15: Validation Accuracy = 0.9492
# Epoch 16: Validation Accuracy = 0.9510
# Epoch 17: Validation Accuracy = 0.9521
# Epoch 18: Validation Accuracy = 0.9534
# Epoch 19: Validation Accuracy = 0.9545
# Epoch 20: Validation Accuracy = 0.9546
# Val Acc: 0.9546 | Runtime: 246.96s | Stopped at epoch 20
#
# MNIST | CNN | enhanced | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.6533
# Epoch 2: Validation Accuracy = 0.7496
# Epoch 3: Validation Accuracy = 0.7991
# Epoch 4: Validation Accuracy = 0.8225
# Epoch 5: Validation Accuracy = 0.8407
# Epoch 6: Validation Accuracy = 0.8548
# Epoch 7: Validation Accuracy = 0.8620
# Epoch 8: Validation Accuracy = 0.8697
# Epoch 9: Validation Accuracy = 0.8762
# Epoch 10: Validation Accuracy = 0.8811
# Epoch 11: Validation Accuracy = 0.8855
# Epoch 12: Validation Accuracy = 0.8891
# Epoch 13: Validation Accuracy = 0.8937
# Epoch 14: Validation Accuracy = 0.8966
# Epoch 15: Validation Accuracy = 0.8975
# Epoch 16: Validation Accuracy = 0.8987
# Epoch 17: Validation Accuracy = 0.9006
# Epoch 18: Validation Accuracy = 0.9025
# Epoch 19: Validation Accuracy = 0.9037
# Epoch 20: Validation Accuracy = 0.9048
# Val Acc: 0.9048 | Runtime: 264.27s | Stopped at epoch 20
#
# MNIST | CNN | enhanced | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.8602
# Epoch 2: Validation Accuracy = 0.8955
# Epoch 3: Validation Accuracy = 0.9100
# Epoch 4: Validation Accuracy = 0.9196
# Epoch 5: Validation Accuracy = 0.9302
# Epoch 6: Validation Accuracy = 0.9311
# Epoch 7: Validation Accuracy = 0.9365
# Epoch 8: Validation Accuracy = 0.9354
# Epoch 9: Validation Accuracy = 0.9407
# Epoch 10: Validation Accuracy = 0.9424
# Epoch 11: Validation Accuracy = 0.9414
# Epoch 12: Validation Accuracy = 0.9451
# Epoch 13: Validation Accuracy = 0.9474
# Epoch 14: Validation Accuracy = 0.9460
# Epoch 15: Validation Accuracy = 0.9459
# Epoch 16: Validation Accuracy = 0.9479
# Epoch 17: Validation Accuracy = 0.9487
# Epoch 18: Validation Accuracy = 0.9475
# Epoch 19: Validation Accuracy = 0.9487
# Epoch 20: Validation Accuracy = 0.9483
# Early stopping at epoch 17
# Val Acc: 0.9487 | Runtime: 244.30s | Stopped at epoch 17
#
# MNIST | CNN | enhanced | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.8949
# Epoch 2: Validation Accuracy = 0.9227
# Epoch 3: Validation Accuracy = 0.9339
# Epoch 4: Validation Accuracy = 0.9434
# Epoch 5: Validation Accuracy = 0.9472
# Epoch 6: Validation Accuracy = 0.9499
# Epoch 7: Validation Accuracy = 0.9547
# Epoch 8: Validation Accuracy = 0.9560
# Epoch 9: Validation Accuracy = 0.9595
# Epoch 10: Validation Accuracy = 0.9616
# Epoch 11: Validation Accuracy = 0.9603
# Epoch 12: Validation Accuracy = 0.9604
# Epoch 13: Validation Accuracy = 0.9641
# Epoch 14: Validation Accuracy = 0.9652
# Epoch 15: Validation Accuracy = 0.9670
# Epoch 16: Validation Accuracy = 0.9649
# Epoch 17: Validation Accuracy = 0.9675
# Epoch 18: Validation Accuracy = 0.9672
# Epoch 19: Validation Accuracy = 0.9685
# Epoch 20: Validation Accuracy = 0.9690
# Val Acc: 0.9690 | Runtime: 303.95s | Stopped at epoch 20
#
# MNIST | CNN | enhanced | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9074
# Epoch 2: Validation Accuracy = 0.9338
# Epoch 3: Validation Accuracy = 0.9412
# Epoch 4: Validation Accuracy = 0.9427
# Epoch 5: Validation Accuracy = 0.9471
# Epoch 6: Validation Accuracy = 0.9479
# Epoch 7: Validation Accuracy = 0.9480
# Epoch 8: Validation Accuracy = 0.9501
# Epoch 9: Validation Accuracy = 0.9473
# Epoch 10: Validation Accuracy = 0.9521
# Epoch 11: Validation Accuracy = 0.9511
# Epoch 12: Validation Accuracy = 0.9528
# Epoch 13: Validation Accuracy = 0.9538
# Epoch 14: Validation Accuracy = 0.9535
# Epoch 15: Validation Accuracy = 0.9560
# Epoch 16: Validation Accuracy = 0.9562
# Epoch 17: Validation Accuracy = 0.9548
# Epoch 18: Validation Accuracy = 0.9556
# Epoch 19: Validation Accuracy = 0.9532
# Early stopping at epoch 16
# Val Acc: 0.9562 | Runtime: 234.75s | Stopped at epoch 16
#
# MNIST | CNN | enhanced | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.8621
# Epoch 2: Validation Accuracy = 0.8933
# Epoch 3: Validation Accuracy = 0.9089
# Epoch 4: Validation Accuracy = 0.9153
# Epoch 5: Validation Accuracy = 0.9245
# Epoch 6: Validation Accuracy = 0.9283
# Epoch 7: Validation Accuracy = 0.9345
# Epoch 8: Validation Accuracy = 0.9390
# Epoch 9: Validation Accuracy = 0.9414
# Epoch 10: Validation Accuracy = 0.9433
# Epoch 11: Validation Accuracy = 0.9453
# Epoch 12: Validation Accuracy = 0.9490
# Epoch 13: Validation Accuracy = 0.9499
# Epoch 14: Validation Accuracy = 0.9515
# Epoch 15: Validation Accuracy = 0.9541
# Epoch 16: Validation Accuracy = 0.9547
# Epoch 17: Validation Accuracy = 0.9565
# Epoch 18: Validation Accuracy = 0.9579
# Epoch 19: Validation Accuracy = 0.9584
# Epoch 20: Validation Accuracy = 0.9590
# Val Acc: 0.9590 | Runtime: 264.91s | Stopped at epoch 20
#
# MNIST | CNN | enhanced | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.9444
# Epoch 2: Validation Accuracy = 0.9621
# Epoch 3: Validation Accuracy = 0.9676
# Epoch 4: Validation Accuracy = 0.9673
# Epoch 5: Validation Accuracy = 0.9711
# Epoch 6: Validation Accuracy = 0.9704
# Epoch 7: Validation Accuracy = 0.9725
# Epoch 8: Validation Accuracy = 0.9731
# Epoch 9: Validation Accuracy = 0.9727
# Epoch 10: Validation Accuracy = 0.9743
# Epoch 11: Validation Accuracy = 0.9749
# Epoch 12: Validation Accuracy = 0.9748
# Epoch 13: Validation Accuracy = 0.9760
# Epoch 14: Validation Accuracy = 0.9752
# Epoch 15: Validation Accuracy = 0.9752
# Epoch 16: Validation Accuracy = 0.9768
# Epoch 17: Validation Accuracy = 0.9770
# Epoch 18: Validation Accuracy = 0.9776
# Epoch 19: Validation Accuracy = 0.9773
# Epoch 20: Validation Accuracy = 0.9765
# Val Acc: 0.9776 | Runtime: 305.04s | Stopped at epoch 18
#
# MNIST | CNN | enhanced | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.8662
# Epoch 2: Validation Accuracy = 0.8940
# Epoch 3: Validation Accuracy = 0.8995
# Epoch 4: Validation Accuracy = 0.9084
# Epoch 5: Validation Accuracy = 0.9138
# Epoch 6: Validation Accuracy = 0.9207
# Epoch 7: Validation Accuracy = 0.9246
# Epoch 8: Validation Accuracy = 0.9295
# Epoch 9: Validation Accuracy = 0.9330
# Epoch 10: Validation Accuracy = 0.9375
# Epoch 11: Validation Accuracy = 0.9374
# Epoch 12: Validation Accuracy = 0.9405
# Epoch 13: Validation Accuracy = 0.9430
# Epoch 14: Validation Accuracy = 0.9452
# Epoch 15: Validation Accuracy = 0.9473
# Epoch 16: Validation Accuracy = 0.9463
# Epoch 17: Validation Accuracy = 0.9478
# Epoch 18: Validation Accuracy = 0.9487
# Epoch 19: Validation Accuracy = 0.9501
# Epoch 20: Validation Accuracy = 0.9498
# Val Acc: 0.9501 | Runtime: 303.19s | Stopped at epoch 19
#
# MNIST | CNN | deeper | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9443
# Epoch 2: Validation Accuracy = 0.9680
# Epoch 3: Validation Accuracy = 0.9736
# Epoch 4: Validation Accuracy = 0.9792
# Epoch 5: Validation Accuracy = 0.9792
# Epoch 6: Validation Accuracy = 0.9813
# Epoch 7: Validation Accuracy = 0.9826
# Epoch 8: Validation Accuracy = 0.9836
# Epoch 9: Validation Accuracy = 0.9847
# Epoch 10: Validation Accuracy = 0.9840
# Epoch 11: Validation Accuracy = 0.9849
# Epoch 12: Validation Accuracy = 0.9842
# Epoch 13: Validation Accuracy = 0.9851
# Epoch 14: Validation Accuracy = 0.9865
# Epoch 15: Validation Accuracy = 0.9867
# Epoch 16: Validation Accuracy = 0.9864
# Epoch 17: Validation Accuracy = 0.9868
# Epoch 18: Validation Accuracy = 0.9873
# Epoch 19: Validation Accuracy = 0.9874
# Epoch 20: Validation Accuracy = 0.9871
# Val Acc: 0.9874 | Runtime: 279.51s | Stopped at epoch 19
#
# MNIST | CNN | deeper | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.8999
# Epoch 2: Validation Accuracy = 0.9428
# Epoch 3: Validation Accuracy = 0.9588
# Epoch 4: Validation Accuracy = 0.9666
# Epoch 5: Validation Accuracy = 0.9728
# Epoch 6: Validation Accuracy = 0.9745
# Epoch 7: Validation Accuracy = 0.9777
# Epoch 8: Validation Accuracy = 0.9790
# Epoch 9: Validation Accuracy = 0.9806
# Epoch 10: Validation Accuracy = 0.9808
# Epoch 11: Validation Accuracy = 0.9815
# Epoch 12: Validation Accuracy = 0.9809
# Epoch 13: Validation Accuracy = 0.9828
# Epoch 14: Validation Accuracy = 0.9833
# Epoch 15: Validation Accuracy = 0.9838
# Epoch 16: Validation Accuracy = 0.9832
# Epoch 17: Validation Accuracy = 0.9845
# Epoch 18: Validation Accuracy = 0.9843
# Epoch 19: Validation Accuracy = 0.9843
# Epoch 20: Validation Accuracy = 0.9845
# Early stopping at epoch 17
# Val Acc: 0.9845 | Runtime: 277.50s | Stopped at epoch 17
#
# MNIST | CNN | deeper | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.8927
# Epoch 2: Validation Accuracy = 0.9318
# Epoch 3: Validation Accuracy = 0.9422
# Epoch 4: Validation Accuracy = 0.9524
# Epoch 5: Validation Accuracy = 0.9589
# Epoch 6: Validation Accuracy = 0.9646
# Epoch 7: Validation Accuracy = 0.9673
# Epoch 8: Validation Accuracy = 0.9701
# Epoch 9: Validation Accuracy = 0.9725
# Epoch 10: Validation Accuracy = 0.9755
# Epoch 11: Validation Accuracy = 0.9767
# Epoch 12: Validation Accuracy = 0.9783
# Epoch 13: Validation Accuracy = 0.9798
# Epoch 14: Validation Accuracy = 0.9806
# Epoch 15: Validation Accuracy = 0.9821
# Epoch 16: Validation Accuracy = 0.9830
# Epoch 17: Validation Accuracy = 0.9837
# Epoch 18: Validation Accuracy = 0.9852
# Epoch 19: Validation Accuracy = 0.9853
# Epoch 20: Validation Accuracy = 0.9858
# Val Acc: 0.9858 | Runtime: 252.99s | Stopped at epoch 20
#
# MNIST | CNN | deeper | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.5559
# Epoch 2: Validation Accuracy = 0.7189
# Epoch 3: Validation Accuracy = 0.7647
# Epoch 4: Validation Accuracy = 0.7930
# Epoch 5: Validation Accuracy = 0.8139
# Epoch 6: Validation Accuracy = 0.8301
# Epoch 7: Validation Accuracy = 0.8412
# Epoch 8: Validation Accuracy = 0.8537
# Epoch 9: Validation Accuracy = 0.8624
# Epoch 10: Validation Accuracy = 0.8706
# Epoch 11: Validation Accuracy = 0.8781
# Epoch 12: Validation Accuracy = 0.8857
# Epoch 13: Validation Accuracy = 0.8897
# Epoch 14: Validation Accuracy = 0.8934
# Epoch 15: Validation Accuracy = 0.8970
# Epoch 16: Validation Accuracy = 0.8987
# Epoch 17: Validation Accuracy = 0.9016
# Epoch 18: Validation Accuracy = 0.9035
# Epoch 19: Validation Accuracy = 0.9052
# Epoch 20: Validation Accuracy = 0.9079
# Val Acc: 0.9079 | Runtime: 276.42s | Stopped at epoch 20
#
# MNIST | CNN | deeper | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.8601
# Epoch 2: Validation Accuracy = 0.9109
# Epoch 3: Validation Accuracy = 0.9343
# Epoch 4: Validation Accuracy = 0.9477
# Epoch 5: Validation Accuracy = 0.9572
# Epoch 6: Validation Accuracy = 0.9629
# Epoch 7: Validation Accuracy = 0.9672
# Epoch 8: Validation Accuracy = 0.9707
# Epoch 9: Validation Accuracy = 0.9725
# Epoch 10: Validation Accuracy = 0.9741
# Epoch 11: Validation Accuracy = 0.9750
# Epoch 12: Validation Accuracy = 0.9771
# Epoch 13: Validation Accuracy = 0.9779
# Epoch 14: Validation Accuracy = 0.9772
# Epoch 15: Validation Accuracy = 0.9792
# Epoch 16: Validation Accuracy = 0.9790
# Epoch 17: Validation Accuracy = 0.9803
# Epoch 18: Validation Accuracy = 0.9808
# Epoch 19: Validation Accuracy = 0.9812
# Epoch 20: Validation Accuracy = 0.9808
# Val Acc: 0.9812 | Runtime: 251.20s | Stopped at epoch 19
#
# MNIST | CNN | deeper | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.8834
# Epoch 2: Validation Accuracy = 0.9295
# Epoch 3: Validation Accuracy = 0.9473
# Epoch 4: Validation Accuracy = 0.9549
# Epoch 5: Validation Accuracy = 0.9606
# Epoch 6: Validation Accuracy = 0.9642
# Epoch 7: Validation Accuracy = 0.9667
# Epoch 8: Validation Accuracy = 0.9690
# Epoch 9: Validation Accuracy = 0.9716
# Epoch 10: Validation Accuracy = 0.9736
# Epoch 11: Validation Accuracy = 0.9758
# Epoch 12: Validation Accuracy = 0.9773
# Epoch 13: Validation Accuracy = 0.9784
# Epoch 14: Validation Accuracy = 0.9797
# Epoch 15: Validation Accuracy = 0.9803
# Epoch 16: Validation Accuracy = 0.9810
# Epoch 17: Validation Accuracy = 0.9820
# Epoch 18: Validation Accuracy = 0.9830
# Epoch 19: Validation Accuracy = 0.9832
# Epoch 20: Validation Accuracy = 0.9839
# Val Acc: 0.9839 | Runtime: 327.84s | Stopped at epoch 20
#
# MNIST | CNN | deeper | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.9718
# Epoch 2: Validation Accuracy = 0.9757
# Epoch 3: Validation Accuracy = 0.9815
# Epoch 4: Validation Accuracy = 0.9831
# Epoch 5: Validation Accuracy = 0.9844
# Epoch 6: Validation Accuracy = 0.9861
# Epoch 7: Validation Accuracy = 0.9851
# Epoch 8: Validation Accuracy = 0.9869
# Epoch 9: Validation Accuracy = 0.9870
# Epoch 10: Validation Accuracy = 0.9882
# Epoch 11: Validation Accuracy = 0.9880
# Epoch 12: Validation Accuracy = 0.9885
# Epoch 13: Validation Accuracy = 0.9877
# Epoch 14: Validation Accuracy = 0.9879
# Epoch 15: Validation Accuracy = 0.9888
# Epoch 16: Validation Accuracy = 0.9882
# Epoch 17: Validation Accuracy = 0.9884
# Epoch 18: Validation Accuracy = 0.9879
# Early stopping at epoch 15
# Val Acc: 0.9888 | Runtime: 228.12s | Stopped at epoch 15
#
# MNIST | CNN | deeper | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.8699
# Epoch 2: Validation Accuracy = 0.9075
# Epoch 3: Validation Accuracy = 0.9235
# Epoch 4: Validation Accuracy = 0.9350
# Epoch 5: Validation Accuracy = 0.9411
# Epoch 6: Validation Accuracy = 0.9487
# Epoch 7: Validation Accuracy = 0.9531
# Epoch 8: Validation Accuracy = 0.9557
# Epoch 9: Validation Accuracy = 0.9587
# Epoch 10: Validation Accuracy = 0.9610
# Epoch 11: Validation Accuracy = 0.9631
# Epoch 12: Validation Accuracy = 0.9646
# Epoch 13: Validation Accuracy = 0.9661
# Epoch 14: Validation Accuracy = 0.9680
# Epoch 15: Validation Accuracy = 0.9684
# Epoch 16: Validation Accuracy = 0.9701
# Epoch 17: Validation Accuracy = 0.9710
# Epoch 18: Validation Accuracy = 0.9723
# Epoch 19: Validation Accuracy = 0.9734
# Epoch 20: Validation Accuracy = 0.9739
# Val Acc: 0.9739 | Runtime: 276.44s | Stopped at epoch 20
#
# MNIST | CNN | deeper | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.9698
# Epoch 2: Validation Accuracy = 0.9816
# Epoch 3: Validation Accuracy = 0.9855
# Epoch 4: Validation Accuracy = 0.9883
# Epoch 5: Validation Accuracy = 0.9884
# Epoch 6: Validation Accuracy = 0.9893
# Epoch 7: Validation Accuracy = 0.9907
# Epoch 8: Validation Accuracy = 0.9909
# Epoch 9: Validation Accuracy = 0.9911
# Epoch 10: Validation Accuracy = 0.9920
# Epoch 11: Validation Accuracy = 0.9921
# Epoch 12: Validation Accuracy = 0.9923
# Epoch 13: Validation Accuracy = 0.9915
# Epoch 14: Validation Accuracy = 0.9930
# Epoch 15: Validation Accuracy = 0.9925
# Epoch 16: Validation Accuracy = 0.9924
# Epoch 17: Validation Accuracy = 0.9926
# Early stopping at epoch 14
# Val Acc: 0.9930 | Runtime: 280.62s | Stopped at epoch 14
#
# MNIST | CNN | deeper | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.8012
# Epoch 2: Validation Accuracy = 0.8761
# Epoch 3: Validation Accuracy = 0.9072
# Epoch 4: Validation Accuracy = 0.9186
# Epoch 5: Validation Accuracy = 0.9275
# Epoch 6: Validation Accuracy = 0.9355
# Epoch 7: Validation Accuracy = 0.9415
# Epoch 8: Validation Accuracy = 0.9452
# Epoch 9: Validation Accuracy = 0.9483
# Epoch 10: Validation Accuracy = 0.9524
# Epoch 11: Validation Accuracy = 0.9569
# Epoch 12: Validation Accuracy = 0.9592
# Epoch 13: Validation Accuracy = 0.9605
# Epoch 14: Validation Accuracy = 0.9646
# Epoch 15: Validation Accuracy = 0.9651
# Epoch 16: Validation Accuracy = 0.9673
# Epoch 17: Validation Accuracy = 0.9692
# Epoch 18: Validation Accuracy = 0.9689
# Epoch 19: Validation Accuracy = 0.9711
# Epoch 20: Validation Accuracy = 0.9722
# Val Acc: 0.9722 | Runtime: 329.54s | Stopped at epoch 20
# Saved to /content/drive/MyDrive/ml_experiment_results/mnist_cnn_results.json
#
# Retraining best CNN model for MNIST...
# Retraining for 14 epochs (no early stopping)...
# Epoch 1/14 complete
# Epoch 2/14 complete
# Epoch 3/14 complete
# Epoch 4/14 complete
# Epoch 5/14 complete
# Epoch 6/14 complete
# Epoch 7/14 complete
# Epoch 8/14 complete
# Epoch 9/14 complete
# Epoch 10/14 complete
# Epoch 11/14 complete
# Epoch 12/14 complete
# Epoch 13/14 complete
# Epoch 14/14 complete
# Test accuracy: 0.9923 | Runtime: 241.76s
#   Model  Architecture  Learning Rate  Batch Size Optimizer  Dropout  \
# 0   CNN      Baseline           0.01          32       SGD      0.2
# 1   CNN        Deeper           0.01          32       SGD      0.2
# 2   CNN      Enhanced           0.01          32       SGD      0.2
# 3   CNN  Best Overall           0.01          32       SGD      0.2
#
#    Stop Epoch  Validation Accuracy  Runtime (min)  Test Accuracy
# 0          19               0.9758       4.960586            NaN
# 1          14               0.9930       4.677077            NaN
# 2          18               0.9776       5.083980            NaN
# 3          14               0.9930       4.029300         0.9923
#
# CIFAR10 | CNN | baseline | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3596
# Epoch 2: Validation Accuracy = 0.4146
# Epoch 3: Validation Accuracy = 0.4322
# Epoch 4: Validation Accuracy = 0.4334
# Epoch 5: Validation Accuracy = 0.4530
# Epoch 6: Validation Accuracy = 0.4532
# Epoch 7: Validation Accuracy = 0.4582
# Epoch 8: Validation Accuracy = 0.4744
# Epoch 9: Validation Accuracy = 0.4644
# Epoch 10: Validation Accuracy = 0.4738
# Epoch 11: Validation Accuracy = 0.4864
# Epoch 12: Validation Accuracy = 0.4880
# Epoch 13: Validation Accuracy = 0.4944
# Epoch 14: Validation Accuracy = 0.4996
# Epoch 15: Validation Accuracy = 0.4984
# Epoch 16: Validation Accuracy = 0.5068
# Epoch 17: Validation Accuracy = 0.5052
# Epoch 18: Validation Accuracy = 0.5056
# Epoch 19: Validation Accuracy = 0.5138
# Epoch 20: Validation Accuracy = 0.5088
# Val Acc: 0.5138 | Runtime: 246.10s | Stopped at epoch 19
#
# CIFAR10 | CNN | baseline | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3228
# Epoch 2: Validation Accuracy = 0.3600
# Epoch 3: Validation Accuracy = 0.4046
# Epoch 4: Validation Accuracy = 0.4216
# Epoch 5: Validation Accuracy = 0.4388
# Epoch 6: Validation Accuracy = 0.4496
# Epoch 7: Validation Accuracy = 0.4574
# Epoch 8: Validation Accuracy = 0.4522
# Epoch 9: Validation Accuracy = 0.4694
# Epoch 10: Validation Accuracy = 0.4706
# Epoch 11: Validation Accuracy = 0.4750
# Epoch 12: Validation Accuracy = 0.4858
# Epoch 13: Validation Accuracy = 0.4920
# Epoch 14: Validation Accuracy = 0.4950
# Epoch 15: Validation Accuracy = 0.5032
# Epoch 16: Validation Accuracy = 0.4988
# Epoch 17: Validation Accuracy = 0.4976
# Epoch 18: Validation Accuracy = 0.5064
# Epoch 19: Validation Accuracy = 0.5092
# Epoch 20: Validation Accuracy = 0.5126
# Val Acc: 0.5126 | Runtime: 244.63s | Stopped at epoch 20
#
# CIFAR10 | CNN | baseline | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.2578
# Epoch 2: Validation Accuracy = 0.3100
# Epoch 3: Validation Accuracy = 0.3372
# Epoch 4: Validation Accuracy = 0.3544
# Epoch 5: Validation Accuracy = 0.3650
# Epoch 6: Validation Accuracy = 0.3760
# Epoch 7: Validation Accuracy = 0.3858
# Epoch 8: Validation Accuracy = 0.3860
# Epoch 9: Validation Accuracy = 0.3966
# Epoch 10: Validation Accuracy = 0.3976
# Epoch 11: Validation Accuracy = 0.3984
# Epoch 12: Validation Accuracy = 0.4026
# Epoch 13: Validation Accuracy = 0.4038
# Epoch 14: Validation Accuracy = 0.4066
# Epoch 15: Validation Accuracy = 0.4160
# Epoch 16: Validation Accuracy = 0.4140
# Epoch 17: Validation Accuracy = 0.4200
# Epoch 18: Validation Accuracy = 0.4230
# Epoch 19: Validation Accuracy = 0.4260
# Epoch 20: Validation Accuracy = 0.4314
# Val Acc: 0.4314 | Runtime: 231.55s | Stopped at epoch 20
#
# CIFAR10 | CNN | baseline | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.1438
# Epoch 2: Validation Accuracy = 0.1544
# Epoch 3: Validation Accuracy = 0.1594
# Epoch 4: Validation Accuracy = 0.1614
# Epoch 5: Validation Accuracy = 0.1616
# Epoch 6: Validation Accuracy = 0.1630
# Epoch 7: Validation Accuracy = 0.1674
# Epoch 8: Validation Accuracy = 0.1702
# Epoch 9: Validation Accuracy = 0.1728
# Epoch 10: Validation Accuracy = 0.1794
# Epoch 11: Validation Accuracy = 0.1862
# Epoch 12: Validation Accuracy = 0.1940
# Epoch 13: Validation Accuracy = 0.2016
# Epoch 14: Validation Accuracy = 0.2106
# Epoch 15: Validation Accuracy = 0.2168
# Epoch 16: Validation Accuracy = 0.2218
# Epoch 17: Validation Accuracy = 0.2262
# Epoch 18: Validation Accuracy = 0.2330
# Epoch 19: Validation Accuracy = 0.2372
# Epoch 20: Validation Accuracy = 0.2390
# Val Acc: 0.2390 | Runtime: 248.11s | Stopped at epoch 20
#
# CIFAR10 | CNN | baseline | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.2760
# Epoch 2: Validation Accuracy = 0.3318
# Epoch 3: Validation Accuracy = 0.3564
# Epoch 4: Validation Accuracy = 0.3768
# Epoch 5: Validation Accuracy = 0.3938
# Epoch 6: Validation Accuracy = 0.3964
# Epoch 7: Validation Accuracy = 0.4136
# Epoch 8: Validation Accuracy = 0.4192
# Epoch 9: Validation Accuracy = 0.4302
# Epoch 10: Validation Accuracy = 0.4368
# Epoch 11: Validation Accuracy = 0.4368
# Epoch 12: Validation Accuracy = 0.4462
# Epoch 13: Validation Accuracy = 0.4460
# Epoch 14: Validation Accuracy = 0.4558
# Epoch 15: Validation Accuracy = 0.4620
# Epoch 16: Validation Accuracy = 0.4622
# Epoch 17: Validation Accuracy = 0.4686
# Epoch 18: Validation Accuracy = 0.4770
# Epoch 19: Validation Accuracy = 0.4748
# Epoch 20: Validation Accuracy = 0.4738
# Val Acc: 0.4770 | Runtime: 232.25s | Stopped at epoch 18
#
# CIFAR10 | CNN | baseline | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.2052
# Epoch 2: Validation Accuracy = 0.2938
# Epoch 3: Validation Accuracy = 0.3178
# Epoch 4: Validation Accuracy = 0.3410
# Epoch 5: Validation Accuracy = 0.3558
# Epoch 6: Validation Accuracy = 0.3686
# Epoch 7: Validation Accuracy = 0.3818
# Epoch 8: Validation Accuracy = 0.3846
# Epoch 9: Validation Accuracy = 0.3938
# Epoch 10: Validation Accuracy = 0.3978
# Epoch 11: Validation Accuracy = 0.4148
# Epoch 12: Validation Accuracy = 0.4114
# Epoch 13: Validation Accuracy = 0.4208
# Epoch 14: Validation Accuracy = 0.4252
# Epoch 15: Validation Accuracy = 0.4296
# Epoch 16: Validation Accuracy = 0.4324
# Epoch 17: Validation Accuracy = 0.4406
# Epoch 18: Validation Accuracy = 0.4466
# Epoch 19: Validation Accuracy = 0.4488
# Epoch 20: Validation Accuracy = 0.4530
# Val Acc: 0.4530 | Runtime: 273.06s | Stopped at epoch 20
#
# CIFAR10 | CNN | baseline | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3896
# Epoch 2: Validation Accuracy = 0.4178
# Epoch 3: Validation Accuracy = 0.4264
# Epoch 4: Validation Accuracy = 0.4560
# Epoch 5: Validation Accuracy = 0.4628
# Epoch 6: Validation Accuracy = 0.4770
# Epoch 7: Validation Accuracy = 0.4848
# Epoch 8: Validation Accuracy = 0.4742
# Epoch 9: Validation Accuracy = 0.4910
# Epoch 10: Validation Accuracy = 0.4926
# Epoch 11: Validation Accuracy = 0.5048
# Epoch 12: Validation Accuracy = 0.4958
# Epoch 13: Validation Accuracy = 0.4968
# Epoch 14: Validation Accuracy = 0.4998
# Early stopping at epoch 11
# Val Acc: 0.5048 | Runtime: 162.96s | Stopped at epoch 11
#
# CIFAR10 | CNN | baseline | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.2070
# Epoch 2: Validation Accuracy = 0.2356
# Epoch 3: Validation Accuracy = 0.2642
# Epoch 4: Validation Accuracy = 0.2846
# Epoch 5: Validation Accuracy = 0.2982
# Epoch 6: Validation Accuracy = 0.3098
# Epoch 7: Validation Accuracy = 0.3224
# Epoch 8: Validation Accuracy = 0.3374
# Epoch 9: Validation Accuracy = 0.3440
# Epoch 10: Validation Accuracy = 0.3532
# Epoch 11: Validation Accuracy = 0.3582
# Epoch 12: Validation Accuracy = 0.3642
# Epoch 13: Validation Accuracy = 0.3656
# Epoch 14: Validation Accuracy = 0.3744
# Epoch 15: Validation Accuracy = 0.3778
# Epoch 16: Validation Accuracy = 0.3842
# Epoch 17: Validation Accuracy = 0.3878
# Epoch 18: Validation Accuracy = 0.3890
# Epoch 19: Validation Accuracy = 0.3960
# Epoch 20: Validation Accuracy = 0.3924
# Val Acc: 0.3960 | Runtime: 243.82s | Stopped at epoch 19
#
# CIFAR10 | CNN | baseline | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3746
# Epoch 2: Validation Accuracy = 0.4382
# Epoch 3: Validation Accuracy = 0.4644
# Epoch 4: Validation Accuracy = 0.4796
# Epoch 5: Validation Accuracy = 0.5070
# Epoch 6: Validation Accuracy = 0.5072
# Epoch 7: Validation Accuracy = 0.5180
# Epoch 8: Validation Accuracy = 0.5358
# Epoch 9: Validation Accuracy = 0.5308
# Epoch 10: Validation Accuracy = 0.5348
# Epoch 11: Validation Accuracy = 0.5478
# Epoch 12: Validation Accuracy = 0.5454
# Epoch 13: Validation Accuracy = 0.5498
# Epoch 14: Validation Accuracy = 0.5620
# Epoch 15: Validation Accuracy = 0.5672
# Epoch 16: Validation Accuracy = 0.5562
# Epoch 17: Validation Accuracy = 0.5594
# Epoch 18: Validation Accuracy = 0.5706
# Epoch 19: Validation Accuracy = 0.5658
# Epoch 20: Validation Accuracy = 0.5790
# Val Acc: 0.5790 | Runtime: 271.91s | Stopped at epoch 20
#
# CIFAR10 | CNN | baseline | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.2480
# Epoch 2: Validation Accuracy = 0.2750
# Epoch 3: Validation Accuracy = 0.3058
# Epoch 4: Validation Accuracy = 0.3146
# Epoch 5: Validation Accuracy = 0.3294
# Epoch 6: Validation Accuracy = 0.3446
# Epoch 7: Validation Accuracy = 0.3518
# Epoch 8: Validation Accuracy = 0.3696
# Epoch 9: Validation Accuracy = 0.3774
# Epoch 10: Validation Accuracy = 0.3784
# Epoch 11: Validation Accuracy = 0.3930
# Epoch 12: Validation Accuracy = 0.3934
# Epoch 13: Validation Accuracy = 0.4016
# Epoch 14: Validation Accuracy = 0.4062
# Epoch 15: Validation Accuracy = 0.4098
# Epoch 16: Validation Accuracy = 0.4146
# Epoch 17: Validation Accuracy = 0.4152
# Epoch 18: Validation Accuracy = 0.4226
# Epoch 19: Validation Accuracy = 0.4268
# Epoch 20: Validation Accuracy = 0.4304
# Val Acc: 0.4304 | Runtime: 272.10s | Stopped at epoch 20
#
# CIFAR10 | CNN | enhanced | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3758
# Epoch 2: Validation Accuracy = 0.4002
# Epoch 3: Validation Accuracy = 0.4100
# Epoch 4: Validation Accuracy = 0.4290
# Epoch 5: Validation Accuracy = 0.4366
# Epoch 6: Validation Accuracy = 0.4348
# Epoch 7: Validation Accuracy = 0.4604
# Epoch 8: Validation Accuracy = 0.4558
# Epoch 9: Validation Accuracy = 0.4616
# Epoch 10: Validation Accuracy = 0.4594
# Epoch 11: Validation Accuracy = 0.4674
# Epoch 12: Validation Accuracy = 0.4618
# Epoch 13: Validation Accuracy = 0.4730
# Epoch 14: Validation Accuracy = 0.4704
# Epoch 15: Validation Accuracy = 0.4680
# Epoch 16: Validation Accuracy = 0.4612
# Early stopping at epoch 13
# Val Acc: 0.4730 | Runtime: 202.01s | Stopped at epoch 13
#
# CIFAR10 | CNN | enhanced | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3756
# Epoch 2: Validation Accuracy = 0.4098
# Epoch 3: Validation Accuracy = 0.4240
# Epoch 4: Validation Accuracy = 0.4372
# Epoch 5: Validation Accuracy = 0.4360
# Epoch 6: Validation Accuracy = 0.4396
# Epoch 7: Validation Accuracy = 0.4478
# Epoch 8: Validation Accuracy = 0.4578
# Epoch 9: Validation Accuracy = 0.4592
# Epoch 10: Validation Accuracy = 0.4628
# Epoch 11: Validation Accuracy = 0.4638
# Epoch 12: Validation Accuracy = 0.4684
# Epoch 13: Validation Accuracy = 0.4624
# Epoch 14: Validation Accuracy = 0.4712
# Epoch 15: Validation Accuracy = 0.4726
# Epoch 16: Validation Accuracy = 0.4670
# Epoch 17: Validation Accuracy = 0.4710
# Epoch 18: Validation Accuracy = 0.4674
# Early stopping at epoch 15
# Val Acc: 0.4726 | Runtime: 226.49s | Stopped at epoch 15
#
# CIFAR10 | CNN | enhanced | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3242
# Epoch 2: Validation Accuracy = 0.3644
# Epoch 3: Validation Accuracy = 0.3844
# Epoch 4: Validation Accuracy = 0.4030
# Epoch 5: Validation Accuracy = 0.4152
# Epoch 6: Validation Accuracy = 0.4294
# Epoch 7: Validation Accuracy = 0.4344
# Epoch 8: Validation Accuracy = 0.4414
# Epoch 9: Validation Accuracy = 0.4498
# Epoch 10: Validation Accuracy = 0.4570
# Epoch 11: Validation Accuracy = 0.4594
# Epoch 12: Validation Accuracy = 0.4696
# Epoch 13: Validation Accuracy = 0.4740
# Epoch 14: Validation Accuracy = 0.4728
# Epoch 15: Validation Accuracy = 0.4764
# Epoch 16: Validation Accuracy = 0.4826
# Epoch 17: Validation Accuracy = 0.4884
# Epoch 18: Validation Accuracy = 0.4870
# Epoch 19: Validation Accuracy = 0.4912
# Epoch 20: Validation Accuracy = 0.4922
# Val Acc: 0.4922 | Runtime: 235.50s | Stopped at epoch 20
#
# CIFAR10 | CNN | enhanced | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.2318
# Epoch 2: Validation Accuracy = 0.2822
# Epoch 3: Validation Accuracy = 0.3078
# Epoch 4: Validation Accuracy = 0.3222
# Epoch 5: Validation Accuracy = 0.3326
# Epoch 6: Validation Accuracy = 0.3500
# Epoch 7: Validation Accuracy = 0.3578
# Epoch 8: Validation Accuracy = 0.3642
# Epoch 9: Validation Accuracy = 0.3712
# Epoch 10: Validation Accuracy = 0.3794
# Epoch 11: Validation Accuracy = 0.3834
# Epoch 12: Validation Accuracy = 0.3930
# Epoch 13: Validation Accuracy = 0.3926
# Epoch 14: Validation Accuracy = 0.3944
# Epoch 15: Validation Accuracy = 0.3992
# Epoch 16: Validation Accuracy = 0.4026
# Epoch 17: Validation Accuracy = 0.4070
# Epoch 18: Validation Accuracy = 0.4124
# Epoch 19: Validation Accuracy = 0.4142
# Epoch 20: Validation Accuracy = 0.4142
# Val Acc: 0.4142 | Runtime: 251.81s | Stopped at epoch 19
#
# CIFAR10 | CNN | enhanced | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3582
# Epoch 2: Validation Accuracy = 0.3830
# Epoch 3: Validation Accuracy = 0.3964
# Epoch 4: Validation Accuracy = 0.4094
# Epoch 5: Validation Accuracy = 0.4112
# Epoch 6: Validation Accuracy = 0.4214
# Epoch 7: Validation Accuracy = 0.4248
# Epoch 8: Validation Accuracy = 0.4278
# Epoch 9: Validation Accuracy = 0.4336
# Epoch 10: Validation Accuracy = 0.4364
# Epoch 11: Validation Accuracy = 0.4274
# Epoch 12: Validation Accuracy = 0.4384
# Epoch 13: Validation Accuracy = 0.4412
# Epoch 14: Validation Accuracy = 0.4388
# Epoch 15: Validation Accuracy = 0.4452
# Epoch 16: Validation Accuracy = 0.4524
# Epoch 17: Validation Accuracy = 0.4466
# Epoch 18: Validation Accuracy = 0.4530
# Epoch 19: Validation Accuracy = 0.4468
# Epoch 20: Validation Accuracy = 0.4538
# Val Acc: 0.4538 | Runtime: 234.13s | Stopped at epoch 20
#
# CIFAR10 | CNN | enhanced | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.4092
# Epoch 2: Validation Accuracy = 0.4346
# Epoch 3: Validation Accuracy = 0.4526
# Epoch 4: Validation Accuracy = 0.4718
# Epoch 5: Validation Accuracy = 0.4862
# Epoch 6: Validation Accuracy = 0.5024
# Epoch 7: Validation Accuracy = 0.4974
# Epoch 8: Validation Accuracy = 0.5078
# Epoch 9: Validation Accuracy = 0.5086
# Epoch 10: Validation Accuracy = 0.5074
# Epoch 11: Validation Accuracy = 0.5036
# Epoch 12: Validation Accuracy = 0.5224
# Epoch 13: Validation Accuracy = 0.5226
# Epoch 14: Validation Accuracy = 0.5264
# Epoch 15: Validation Accuracy = 0.5312
# Epoch 16: Validation Accuracy = 0.5264
# Epoch 17: Validation Accuracy = 0.5340
# Epoch 18: Validation Accuracy = 0.5422
# Epoch 19: Validation Accuracy = 0.5470
# Epoch 20: Validation Accuracy = 0.5394
# Val Acc: 0.5470 | Runtime: 286.05s | Stopped at epoch 19
#
# CIFAR10 | CNN | enhanced | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3708
# Epoch 2: Validation Accuracy = 0.4122
# Epoch 3: Validation Accuracy = 0.4096
# Epoch 4: Validation Accuracy = 0.4192
# Epoch 5: Validation Accuracy = 0.4220
# Epoch 6: Validation Accuracy = 0.4302
# Epoch 7: Validation Accuracy = 0.4328
# Epoch 8: Validation Accuracy = 0.4342
# Epoch 9: Validation Accuracy = 0.4400
# Epoch 10: Validation Accuracy = 0.4484
# Epoch 11: Validation Accuracy = 0.4438
# Epoch 12: Validation Accuracy = 0.4514
# Epoch 13: Validation Accuracy = 0.4490
# Epoch 14: Validation Accuracy = 0.4522
# Epoch 15: Validation Accuracy = 0.4526
# Epoch 16: Validation Accuracy = 0.4556
# Epoch 17: Validation Accuracy = 0.4392
# Epoch 18: Validation Accuracy = 0.4554
# Epoch 19: Validation Accuracy = 0.4550
# Early stopping at epoch 16
# Val Acc: 0.4556 | Runtime: 227.70s | Stopped at epoch 16
#
# CIFAR10 | CNN | enhanced | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3550
# Epoch 2: Validation Accuracy = 0.3912
# Epoch 3: Validation Accuracy = 0.4154
# Epoch 4: Validation Accuracy = 0.4286
# Epoch 5: Validation Accuracy = 0.4384
# Epoch 6: Validation Accuracy = 0.4534
# Epoch 7: Validation Accuracy = 0.4640
# Epoch 8: Validation Accuracy = 0.4670
# Epoch 9: Validation Accuracy = 0.4816
# Epoch 10: Validation Accuracy = 0.4840
# Epoch 11: Validation Accuracy = 0.4914
# Epoch 12: Validation Accuracy = 0.4992
# Epoch 13: Validation Accuracy = 0.4960
# Epoch 14: Validation Accuracy = 0.5034
# Epoch 15: Validation Accuracy = 0.5054
# Epoch 16: Validation Accuracy = 0.5064
# Epoch 17: Validation Accuracy = 0.5104
# Epoch 18: Validation Accuracy = 0.5180
# Epoch 19: Validation Accuracy = 0.5192
# Epoch 20: Validation Accuracy = 0.5186
# Val Acc: 0.5192 | Runtime: 253.98s | Stopped at epoch 19
#
# CIFAR10 | CNN | enhanced | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.4380
# Epoch 2: Validation Accuracy = 0.4772
# Epoch 3: Validation Accuracy = 0.4878
# Epoch 4: Validation Accuracy = 0.5128
# Epoch 5: Validation Accuracy = 0.5228
# Epoch 6: Validation Accuracy = 0.5376
# Epoch 7: Validation Accuracy = 0.5342
# Epoch 8: Validation Accuracy = 0.5484
# Epoch 9: Validation Accuracy = 0.5492
# Epoch 10: Validation Accuracy = 0.5494
# Epoch 11: Validation Accuracy = 0.5464
# Epoch 12: Validation Accuracy = 0.5444
# Epoch 13: Validation Accuracy = 0.5584
# Epoch 14: Validation Accuracy = 0.5496
# Epoch 15: Validation Accuracy = 0.5560
# Epoch 16: Validation Accuracy = 0.5620
# Epoch 17: Validation Accuracy = 0.5662
# Epoch 18: Validation Accuracy = 0.5604
# Epoch 19: Validation Accuracy = 0.5528
# Epoch 20: Validation Accuracy = 0.5674
# Val Acc: 0.5674 | Runtime: 288.72s | Stopped at epoch 20
#
# CIFAR10 | CNN | enhanced | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3160
# Epoch 2: Validation Accuracy = 0.3492
# Epoch 3: Validation Accuracy = 0.3660
# Epoch 4: Validation Accuracy = 0.3824
# Epoch 5: Validation Accuracy = 0.3926
# Epoch 6: Validation Accuracy = 0.3992
# Epoch 7: Validation Accuracy = 0.4090
# Epoch 8: Validation Accuracy = 0.4122
# Epoch 9: Validation Accuracy = 0.4238
# Epoch 10: Validation Accuracy = 0.4202
# Epoch 11: Validation Accuracy = 0.4232
# Epoch 12: Validation Accuracy = 0.4242
# Epoch 13: Validation Accuracy = 0.4296
# Epoch 14: Validation Accuracy = 0.4376
# Epoch 15: Validation Accuracy = 0.4320
# Epoch 16: Validation Accuracy = 0.4430
# Epoch 17: Validation Accuracy = 0.4466
# Epoch 18: Validation Accuracy = 0.4450
# Epoch 19: Validation Accuracy = 0.4536
# Epoch 20: Validation Accuracy = 0.4492
# Val Acc: 0.4536 | Runtime: 288.56s | Stopped at epoch 19
#
# CIFAR10 | CNN | deeper | LR=0.001 | Batch=64 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3966
# Epoch 2: Validation Accuracy = 0.4452
# Epoch 3: Validation Accuracy = 0.4828
# Epoch 4: Validation Accuracy = 0.4998
# Epoch 5: Validation Accuracy = 0.5256
# Epoch 6: Validation Accuracy = 0.5444
# Epoch 7: Validation Accuracy = 0.5530
# Epoch 8: Validation Accuracy = 0.5610
# Epoch 9: Validation Accuracy = 0.5648
# Epoch 10: Validation Accuracy = 0.5790
# Epoch 11: Validation Accuracy = 0.5784
# Epoch 12: Validation Accuracy = 0.5826
# Epoch 13: Validation Accuracy = 0.5934
# Epoch 14: Validation Accuracy = 0.5950
# Epoch 15: Validation Accuracy = 0.6020
# Epoch 16: Validation Accuracy = 0.5920
# Epoch 17: Validation Accuracy = 0.6038
# Epoch 18: Validation Accuracy = 0.5934
# Epoch 19: Validation Accuracy = 0.6074
# Epoch 20: Validation Accuracy = 0.6152
# Val Acc: 0.6152 | Runtime: 266.27s | Stopped at epoch 20
#
# CIFAR10 | CNN | deeper | LR=0.01 | Batch=64 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.3336
# Epoch 2: Validation Accuracy = 0.4178
# Epoch 3: Validation Accuracy = 0.4468
# Epoch 4: Validation Accuracy = 0.4656
# Epoch 5: Validation Accuracy = 0.4760
# Epoch 6: Validation Accuracy = 0.4940
# Epoch 7: Validation Accuracy = 0.4982
# Epoch 8: Validation Accuracy = 0.5080
# Epoch 9: Validation Accuracy = 0.5050
# Epoch 10: Validation Accuracy = 0.5230
# Epoch 11: Validation Accuracy = 0.5232
# Epoch 12: Validation Accuracy = 0.5396
# Epoch 13: Validation Accuracy = 0.5432
# Epoch 14: Validation Accuracy = 0.5472
# Epoch 15: Validation Accuracy = 0.5374
# Epoch 16: Validation Accuracy = 0.5520
# Epoch 17: Validation Accuracy = 0.5190
# Epoch 18: Validation Accuracy = 0.5650
# Epoch 19: Validation Accuracy = 0.5644
# Epoch 20: Validation Accuracy = 0.5590
# Val Acc: 0.5650 | Runtime: 263.46s | Stopped at epoch 18
#
# CIFAR10 | CNN | deeper | LR=0.0001 | Batch=128 | Opt=Adam | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3550
# Epoch 2: Validation Accuracy = 0.4084
# Epoch 3: Validation Accuracy = 0.4336
# Epoch 4: Validation Accuracy = 0.4548
# Epoch 5: Validation Accuracy = 0.4738
# Epoch 6: Validation Accuracy = 0.4900
# Epoch 7: Validation Accuracy = 0.5054
# Epoch 8: Validation Accuracy = 0.5174
# Epoch 9: Validation Accuracy = 0.5290
# Epoch 10: Validation Accuracy = 0.5362
# Epoch 11: Validation Accuracy = 0.5428
# Epoch 12: Validation Accuracy = 0.5556
# Epoch 13: Validation Accuracy = 0.5598
# Epoch 14: Validation Accuracy = 0.5702
# Epoch 15: Validation Accuracy = 0.5742
# Epoch 16: Validation Accuracy = 0.5826
# Epoch 17: Validation Accuracy = 0.5880
# Epoch 18: Validation Accuracy = 0.5870
# Epoch 19: Validation Accuracy = 0.6004
# Epoch 20: Validation Accuracy = 0.6042
# Val Acc: 0.6042 | Runtime: 244.06s | Stopped at epoch 20
#
# CIFAR10 | CNN | deeper | LR=0.0001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.1710
# Epoch 2: Validation Accuracy = 0.2196
# Epoch 3: Validation Accuracy = 0.2518
# Epoch 4: Validation Accuracy = 0.2676
# Epoch 5: Validation Accuracy = 0.2846
# Epoch 6: Validation Accuracy = 0.2978
# Epoch 7: Validation Accuracy = 0.3034
# Epoch 8: Validation Accuracy = 0.3128
# Epoch 9: Validation Accuracy = 0.3152
# Epoch 10: Validation Accuracy = 0.3262
# Epoch 11: Validation Accuracy = 0.3290
# Epoch 12: Validation Accuracy = 0.3396
# Epoch 13: Validation Accuracy = 0.3468
# Epoch 14: Validation Accuracy = 0.3476
# Epoch 15: Validation Accuracy = 0.3534
# Epoch 16: Validation Accuracy = 0.3554
# Epoch 17: Validation Accuracy = 0.3672
# Epoch 18: Validation Accuracy = 0.3630
# Epoch 19: Validation Accuracy = 0.3716
# Epoch 20: Validation Accuracy = 0.3776
# Val Acc: 0.3776 | Runtime: 264.81s | Stopped at epoch 20
#
# CIFAR10 | CNN | deeper | LR=0.01 | Batch=128 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.2708
# Epoch 2: Validation Accuracy = 0.3604
# Epoch 3: Validation Accuracy = 0.3990
# Epoch 4: Validation Accuracy = 0.4186
# Epoch 5: Validation Accuracy = 0.4370
# Epoch 6: Validation Accuracy = 0.4416
# Epoch 7: Validation Accuracy = 0.4614
# Epoch 8: Validation Accuracy = 0.4648
# Epoch 9: Validation Accuracy = 0.4780
# Epoch 10: Validation Accuracy = 0.4900
# Epoch 11: Validation Accuracy = 0.4848
# Epoch 12: Validation Accuracy = 0.4894
# Epoch 13: Validation Accuracy = 0.4796
# Early stopping at epoch 10
# Val Acc: 0.4900 | Runtime: 157.78s | Stopped at epoch 10
#
# CIFAR10 | CNN | deeper | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3862
# Epoch 2: Validation Accuracy = 0.4182
# Epoch 3: Validation Accuracy = 0.4496
# Epoch 4: Validation Accuracy = 0.4660
# Epoch 5: Validation Accuracy = 0.4826
# Epoch 6: Validation Accuracy = 0.4968
# Epoch 7: Validation Accuracy = 0.5088
# Epoch 8: Validation Accuracy = 0.5314
# Epoch 9: Validation Accuracy = 0.5454
# Epoch 10: Validation Accuracy = 0.5548
# Epoch 11: Validation Accuracy = 0.5548
# Epoch 12: Validation Accuracy = 0.5730
# Epoch 13: Validation Accuracy = 0.5786
# Epoch 14: Validation Accuracy = 0.5868
# Epoch 15: Validation Accuracy = 0.5950
# Epoch 16: Validation Accuracy = 0.6046
# Epoch 17: Validation Accuracy = 0.6024
# Epoch 18: Validation Accuracy = 0.6162
# Epoch 19: Validation Accuracy = 0.6188
# Epoch 20: Validation Accuracy = 0.6236
# Val Acc: 0.6236 | Runtime: 307.62s | Stopped at epoch 20
#
# CIFAR10 | CNN | deeper | LR=0.01 | Batch=128 | Opt=Adam | Drop=0.5
# Epoch 1: Validation Accuracy = 0.4474
# Epoch 2: Validation Accuracy = 0.4608
# Epoch 3: Validation Accuracy = 0.4864
# Epoch 4: Validation Accuracy = 0.4984
# Epoch 5: Validation Accuracy = 0.5180
# Epoch 6: Validation Accuracy = 0.5268
# Epoch 7: Validation Accuracy = 0.5192
# Epoch 8: Validation Accuracy = 0.5414
# Epoch 9: Validation Accuracy = 0.5536
# Epoch 10: Validation Accuracy = 0.5622
# Epoch 11: Validation Accuracy = 0.5758
# Epoch 12: Validation Accuracy = 0.5678
# Epoch 13: Validation Accuracy = 0.5708
# Epoch 14: Validation Accuracy = 0.5718
# Early stopping at epoch 11
# Val Acc: 0.5758 | Runtime: 170.48s | Stopped at epoch 11
#
# CIFAR10 | CNN | deeper | LR=0.001 | Batch=64 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.3196
# Epoch 2: Validation Accuracy = 0.3682
# Epoch 3: Validation Accuracy = 0.4062
# Epoch 4: Validation Accuracy = 0.4266
# Epoch 5: Validation Accuracy = 0.4388
# Epoch 6: Validation Accuracy = 0.4510
# Epoch 7: Validation Accuracy = 0.4570
# Epoch 8: Validation Accuracy = 0.4686
# Epoch 9: Validation Accuracy = 0.4790
# Epoch 10: Validation Accuracy = 0.4868
# Epoch 11: Validation Accuracy = 0.4894
# Epoch 12: Validation Accuracy = 0.5012
# Epoch 13: Validation Accuracy = 0.5032
# Epoch 14: Validation Accuracy = 0.5160
# Epoch 15: Validation Accuracy = 0.5128
# Epoch 16: Validation Accuracy = 0.5292
# Epoch 17: Validation Accuracy = 0.5356
# Epoch 18: Validation Accuracy = 0.5218
# Epoch 19: Validation Accuracy = 0.5476
# Epoch 20: Validation Accuracy = 0.5340
# Val Acc: 0.5476 | Runtime: 263.36s | Stopped at epoch 19
#
# CIFAR10 | CNN | deeper | LR=0.01 | Batch=32 | Opt=SGD | Drop=0.2
# Epoch 1: Validation Accuracy = 0.4934
# Epoch 2: Validation Accuracy = 0.5524
# Epoch 3: Validation Accuracy = 0.6056
# Epoch 4: Validation Accuracy = 0.6246
# Epoch 5: Validation Accuracy = 0.6494
# Epoch 6: Validation Accuracy = 0.6318
# Epoch 7: Validation Accuracy = 0.6562
# Epoch 8: Validation Accuracy = 0.6750
# Epoch 9: Validation Accuracy = 0.6732
# Epoch 10: Validation Accuracy = 0.6884
# Epoch 11: Validation Accuracy = 0.6966
# Epoch 12: Validation Accuracy = 0.6956
# Epoch 13: Validation Accuracy = 0.7092
# Epoch 14: Validation Accuracy = 0.7144
# Epoch 15: Validation Accuracy = 0.7200
# Epoch 16: Validation Accuracy = 0.7246
# Epoch 17: Validation Accuracy = 0.7214
# Epoch 18: Validation Accuracy = 0.7292
# Epoch 19: Validation Accuracy = 0.7302
# Epoch 20: Validation Accuracy = 0.7228
# Val Acc: 0.7302 | Runtime: 307.31s | Stopped at epoch 19
#
# CIFAR10 | CNN | deeper | LR=0.001 | Batch=32 | Opt=SGD | Drop=0.5
# Epoch 1: Validation Accuracy = 0.2542
# Epoch 2: Validation Accuracy = 0.3096
# Epoch 3: Validation Accuracy = 0.3532
# Epoch 4: Validation Accuracy = 0.3784
# Epoch 5: Validation Accuracy = 0.3982
# Epoch 6: Validation Accuracy = 0.4074
# Epoch 7: Validation Accuracy = 0.4240
# Epoch 8: Validation Accuracy = 0.4244
# Epoch 9: Validation Accuracy = 0.4390
# Epoch 10: Validation Accuracy = 0.4528
# Epoch 11: Validation Accuracy = 0.4590
# Epoch 12: Validation Accuracy = 0.4602
# Epoch 13: Validation Accuracy = 0.4818
# Epoch 14: Validation Accuracy = 0.4812
# Epoch 15: Validation Accuracy = 0.4844
# Epoch 16: Validation Accuracy = 0.4950
# Epoch 17: Validation Accuracy = 0.4924
# Epoch 18: Validation Accuracy = 0.4938
# Epoch 19: Validation Accuracy = 0.5040
# Epoch 20: Validation Accuracy = 0.5042
# Val Acc: 0.5042 | Runtime: 306.79s | Stopped at epoch 20
# Saved to /content/drive/MyDrive/ml_experiment_results/cifar10_cnn_results.json
#
# Retraining best CNN model for CIFAR10...
# Retraining for 19 epochs (no early stopping)...
# Epoch 1/19 complete
# Epoch 2/19 complete
# Epoch 3/19 complete
# Epoch 4/19 complete
# Epoch 5/19 complete
# Epoch 6/19 complete
# Epoch 7/19 complete
# Epoch 8/19 complete
# Epoch 9/19 complete
# Epoch 10/19 complete
# Epoch 11/19 complete
# Epoch 12/19 complete
# Epoch 13/19 complete
# Epoch 14/19 complete
# Epoch 15/19 complete
# Epoch 16/19 complete
# Epoch 17/19 complete
# Epoch 18/19 complete
# Epoch 19/19 complete
# Test accuracy: 0.7442 | Runtime: 300.73s
#   Model  Architecture  Learning Rate  Batch Size Optimizer  Dropout  \
# 0   CNN      Baseline           0.01          32       SGD      0.2
# 1   CNN        Deeper           0.01          32       SGD      0.2
# 2   CNN      Enhanced           0.01          32       SGD      0.2
# 3   CNN  Best Overall           0.01          32       SGD      0.2
#
#    Stop Epoch  Validation Accuracy  Runtime (min)  Test Accuracy
# 0          20               0.5790       4.531758            NaN
# 1          19               0.7302       5.121911            NaN
# 2          20               0.5674       4.811990            NaN
# 3          19               0.7302       5.012137         0.7442

# %%
# Combine results - creates one combined table per dataset
table = combine_results(CONFIG)
table_final = pd.DataFrame(table)
table_final
# Out:
# Model Architecture  Learning Rate  Batch Size Optimizer  Dropout  Stop Epoch  Validation Accuracy  Runtime (min)  Test Accuracy
#   MLP         Deep           0.01          32       SGD      0.2          18               0.9836       3.396692            NaN
#   MLP       Medium           0.01          32       SGD      0.2           8               0.9795       1.691885            NaN
#   MLP      Shallow           0.01          32       SGD      0.2          20               0.9790       2.811602            NaN
#   MLP Best Overall           0.01          32       SGD      0.2          18               0.9836       3.217230         0.9829
#   CNN     Baseline           0.01          32       SGD      0.2          19               0.9758       4.960586            NaN
#   CNN       Deeper           0.01          32       SGD      0.2          14               0.9930       4.677077            NaN
#   CNN     Enhanced           0.01          32       SGD      0.2          18               0.9776       5.083980            NaN
#   CNN Best Overall           0.01          32       SGD      0.2          14               0.9930       4.029300         0.9923
# Model Architecture  Learning Rate  Batch Size Optimizer  Dropout  Stop Epoch  Validation Accuracy  Runtime (min)  Test Accuracy
#   MLP         Deep         0.0001         128      Adam      0.2          19               0.4934       2.428194            NaN
#   MLP       Medium         0.0010          32       SGD      0.2          20               0.5104       3.019484            NaN
#   MLP      Shallow         0.0010          32       SGD      0.2          20               0.5042       2.740058            NaN
#   MLP Best Overall         0.0010          32       SGD      0.2          20               0.5104       3.151721         0.5105
#   CNN     Baseline         0.0100          32       SGD      0.2          20               0.5790       4.531758            NaN
#   CNN       Deeper         0.0100          32       SGD      0.2          19               0.7302       5.121911            NaN
#   CNN     Enhanced         0.0100          32       SGD      0.2          20               0.5674       4.811990            NaN
#   CNN Best Overall         0.0100          32       SGD      0.2          19               0.7302       5.012137         0.7442
# Empty DataFrame
# Columns: []
# Index: []
